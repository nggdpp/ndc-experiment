# %% [markdown]
# I ran through and did some utility work on the items in ScienceBase that we are likely to keep in that part of the infrastructure as we work to rearchitect how the actual items within collections are dealt with. I applied three different tags to items depending on their function. These come from a new vocabulary I set up in ScienceBase-Vocab, and those are shown below.

# %%
import requests
from IPython.display import display

parentId = '4f4e4760e4b07f02db47dfb4'
queryRoot = 'https://www.sciencebase.gov/catalog/items?format=json&max=1000&'

# %% [markdown]
# These are the terms I used to essentially classify the Items that will remain in ScienceBase as to their function. In the immediate term, this will let me easily tease out the items that represent actual collections where I should expect to find either some method of interfacing with the items in the collection (file, web link, etc.) or else nothing at the moment. The collection items are also where we will concentrate efforts on metadata improvement.

# %%
item_type_vocab = requests.get('https://www.sciencebase.gov/vocab/5bf3f7bce4b00ce5fb627d57/terms?nodeType=term&parentId=5bf3f7bce4b00ce5fb627d57&max=10&offset=0&format=json').json()

item_types = [{'name':t['name'],'label':t['label'],'description':t['description'],'scheme':t['scheme']} for t in item_type_vocab['list']]

display(item_types)
# Out:
# [{'description': 'Item that represents a logical collection of physical data items managed by an organization contributing to the National Digital Catalog. These are core metadata items for which we expect to find full metadata describing the collection and a method of accessing the contents in the collection.',
#   'label': 'NDC Collection',
#   'name': 'ndc_collection',
#   'scheme': 'https://www.sciencebase.gov/vocab/category/NGGDPP/nggdpp_collection_types'},
#  {'description': 'Denotes a ScienceBase Item that functions as an organizational folder within the National Digital Catalog.',
#   'label': 'NDC Folder',
#   'name': 'ndc_folder',
#   'scheme': 'https://www.sciencebase.gov/vocab/category/NGGDPP/nggdpp_collection_types'},
#  {'description': 'Item that represents a contributing organization. Used to set permissions in ScienceBase to allow management access by members of the organization.',
#   'label': 'NDC Organization',
#   'name': 'ndc_organization',
#   'scheme': 'https://www.sciencebase.gov/vocab/category/NGGDPP/nggdpp_collection_types'}]

# %% [markdown]
# # Organizations
#
# Organization records form the essential containers for managing collections in the NDC. The following sections pull organization items and start to set things up to run some health checks on the organization records.

# %%
tag_scheme_orgs = next(({'name':ts['name'],'scheme':ts['scheme']} for ts in item_types if ts['name'] == 'ndc_organization'), None)
fields_orgs = 'title,contacts,spatial'
sb_query_orgs = f'{queryRoot}fields={fields_orgs}&folderId={parentId}&filter=tags%3D{tag_scheme_orgs}'
print(sb_query_orgs)
# Out:
# https://www.sciencebase.gov/catalog/items?format=json&max=1000&fields=title,contacts,spatial&folderId=4f4e4760e4b07f02db47dfb4&filter=tags%3D{'name': 'ndc_organization', 'scheme': 'https://www.sciencebase.gov/vocab/category/NGGDPP/nggdpp_collection_types'}

# %%
# Retrieve the org items
r_ndc_org = requests.get(sb_query_orgs).json()

# %% [markdown]
# I pulled two essential properties for the org items that will likely be used to help improve metadata for the collection items in these containers:
#
# * Contacts contains a "Data Owner" type contact that should be a reasonably populated responsible party entity for these records. These should be reviewed for current information as they look like contacts that I added a long time ago to the ScienceBase Directory. I did go through and do a little cleanup manually in ScienceBase in a few cases where I did not see Data Owner contacts listed.
# * The spatial property here contains a reasonable bounding box for most of the items generated by tying a state ID to the items in ScienceBase. This might be used to generate a bounding box for collection items to build at least reasonable harvestable metadata for cases where there are not actual items presented in some way as yet.
#
# Note that in going through and classifying everything in the NDC, I came across a few other items buried a little ways down the hiearchy that I classed as "ndc_organization." So it is not just the top-level items in the NDC collection that are considered organizations.

# %%
print(len(r_ndc_org['items']))
display(r_ndc_org['items'])
# Out:
# 48
# [{'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NDLogo.gif',
#     'name': 'North Dakota Geological Survey',
#     'oldPartyId': 18256,
#     'onlineResource': 'https://www.dmr.nd.gov/ndgs/',
#     'primaryLocation': {'mailAddress': {'city': 'Bismarck',
#       'line1': '600 East Boulevard Avenue',
#       'state': 'ND',
#       'zip': '58505-0840'},
#      'name': 'North Dakota Geological Survey',
#      'officePhone': '7013288000',
#      'streetAddress': {'city': 'Bismarck',
#       'line1': '1016 E. Calgary Ave.',
#       'state': 'ND',
#       'zip': '58503'}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NDLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfe0',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfe0'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfe0'}},
#   'spatial': {'boundingBox': {'maxX': -96.554509,
#     'maxY': 49.000691,
#     'minX': -104.048917667,
#     'minY': 45.935018},
#    'representationalPoint': [-100.3017133335, 47.4678545],
#    'representationalPointIsDerived': True},
#   'title': 'North Dakota Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'ask.geology@tn.gov',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logos/TNLogoLarge.png',
#     'name': 'Tennessee Geological Survey',
#     'oldPartyId': 18234,
#     'onlineResource': 'https://www.tn.gov/environment/section/geo-geology',
#     'primaryLocation': {'mailAddress': {'city': 'Nashville',
#       'line1': '312 Rosa L. Parks Ave',
#       'state': 'TN',
#       'zip': '37243'},
#      'name': 'Tennessee Geological Survey',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logos/TNLogoSmall.png',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dfee',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dfee'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dfee'}},
#   'spatial': {'boundingBox': {'maxX': -81.6469,
#     'maxY': 36.678118,
#     'minX': -90.310299667,
#     'minY': 34.982927},
#    'representationalPoint': [-85.9785998335, 35.8305225],
#    'representationalPointIsDerived': True},
#   'title': 'Tennessee Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'mgs@maine.gov',
#     'logoUrl': 'http://www.maine.gov/dacf/mgs/images/logo_geology.png',
#     'name': 'Maine Geological Survey',
#     'oldPartyId': 18251,
#     'onlineResource': 'http://www.maine.gov/dacf/mgs',
#     'primaryLocation': {'mailAddress': {'city': 'Augusta',
#       'line1': '93 State House Station',
#       'state': 'Maine',
#       'zip': '04333'},
#      'name': 'Maine Geological Survey',
#      'officePhone': '2072872801',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfc8',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfc8'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfc8'}},
#   'spatial': {'boundingBox': {'maxX': -66.949827,
#     'maxY': 47.459691333,
#     'minX': -71.084336,
#     'minY': 43.064944667},
#    'representationalPoint': [-69.01708149999999, 45.262318],
#    'representationalPointIsDerived': True},
#   'title': 'Maine Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'KGSMail@uky.edu',
#     'logoUrl': 'http://www.uky.edu/KGS/images/i-kgs.gif',
#     'name': 'Kentucky Geological Survey',
#     'oldPartyId': 18237,
#     'onlineResource': 'http://www.uky.edu/KGS/',
#     'primaryLocation': {'building': 'Mining and Minerals Resources, Room 228',
#      'description': 'University of Kentucky',
#      'mailAddress': {'city': 'Lexington',
#       'country': 'USA',
#       'line1': '228 MMRB',
#       'line2': 'University of Kentucky',
#       'state': 'KY',
#       'zip': '40506-0107'},
#      'name': 'Kentucky Geological Survey',
#      'officePhone': '8592575500',
#      'shortName': 'KGS',
#      'streetAddress': {'city': 'Lexington',
#       'country': 'USA',
#       'line1': '504 Rose Street',
#       'line2': 'Mining and Minerals Resources Building, RM 228',
#       'state': 'KY',
#       'zip': '40506-0107'}},
#     'smallLogoUrl': 'http://www.uky.edu/KGS/images/i-kgs.gif',
#     'type': 'Data Owner'},
#    {'active': True,
#     'company': 'Kentucky Geological Survey',
#     'contactType': 'person',
#     'email': 'doug@uky.edu',
#     'firstName': 'Doug',
#     'jobTitle': 'Section Head',
#     'lastName': 'Curl',
#     'name': 'Doug Curl',
#     'oldPartyId': 15019,
#     'organization': {'directoryId': '18237',
#      'displayText': 'Kentucky Geological Survey'},
#     'personalTitle': 'Head Geoscience Information Management Section',
#     'primaryLocation': {'mailAddress': {},
#      'officePhone': '859-323-0519',
#      'streetAddress': {}},
#     'type': 'Contact'}],
#   'id': '4f4e4760e4b07f02db47dfb5',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4760e4b07f02db47dfb5'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4760e4b07f02db47dfb5'}},
#   'spatial': {'boundingBox': {'maxX': -81.964973,
#     'maxY': 39.147455333,
#     'minX': -89.571508667,
#     'minY': 36.497127333},
#    'representationalPoint': [-85.7682408335, 37.822291333],
#    'representationalPointIsDerived': True},
#   'title': 'Kentucky Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'highlighted': True,
#     'name': 'California Geological Survey',
#     'oldPartyId': 59936,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47e007',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47e007'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47e007'}},
#   'spatial': {'boundingBox': {'maxX': -114.131202697754,
#     'maxY': 42.009521484375,
#     'minX': -124.409591674805,
#     'minY': 32.5341529846191},
#    'representationalPoint': [-120.8356905061661, 36.22128615558985],
#    'representationalPointIsDerived': True},
#   'title': 'California Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'highlighted': True,
#     'name': 'Alaska Division of Geological & Geophysical Surveys',
#     'oldPartyId': 18239,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47e002',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47e002'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47e002'}},
#   'spatial': {'representationalPoint': [-151.04926654600615,
#     58.95841928285469],
#    'representationalPointIsDerived': True},
#   'title': 'Alaska Division of Geological and Geophysical Surveys'},
#  {'contacts': [{'active': True,
#     'aliases': ['CRC', 'CORE RESEARCH CENTER'],
#     'contactType': 'organization',
#     'description': 'Core Research Center',
#     'fbmsCodes': ['GGHIER0000', 'GGHMGN0000'],
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/USGSLogo.gif',
#     'name': 'Core Research Center',
#     'oldPartyId': 17172,
#     'onlineResource': 'http://geology.cr.usgs.gov/crc/',
#     'primaryLocation': {'building': 'DFC Bldg 810',
#      'buildingCode': 'KBT',
#      'mailAddress': {'city': 'Denver',
#       'country': 'USA',
#       'line1': 'Box 25046',
#       'line2': 'Mailstop 150',
#       'state': 'CO',
#       'zip': '80225-0046'},
#      'name': 'Denver Federal Center - DFC Bldg 810 [KBT]',
#      'shortName': 'DFC, Bldg 810, KBT, MS 150',
#      'streetAddress': {'city': 'Lakewood',
#       'country': 'USA',
#       'line1': 'West 6th Ave. & Kipling St.',
#       'line2': 'DFC Bldg. 810',
#       'state': 'CO',
#       'zip': '80225-0046'}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/USGSLogo.gif',
#     'type': 'Contact'},
#    {'active': True,
#     'contactType': 'person',
#     'email': 'crc@usgs.gov',
#     'firstName': 'GS-G',
#     'lastName': 'Core Research Center',
#     'name': 'GS-G Core Research Center',
#     'oldPartyId': 61560,
#     'primaryLocation': {'mailAddress': {},
#      'name': 'CN=GS-G Core Research Center,OU=Resources,OU=Messaging,DC=gs,DC=doi,DC=net - Primary Location',
#      'streetAddress': {}},
#     'type': 'Contact'}],
#   'id': '4f4e4760e4b07f02db47dfb9',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4760e4b07f02db47dfb9'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4760e4b07f02db47dfb9'}},
#   'spatial': {'boundingBox': {'maxX': -105.126928688551,
#     'maxY': 39.7159460129284,
#     'minX': -105.126928688551,
#     'minY': 39.7159460129284},
#    'representationalPoint': [-105.126928688551, 39.7159460129284],
#    'representationalPointIsDerived': True},
#   'title': 'USGS Core Research Center'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'pubsales@mtech.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/MTLogo.gif',
#     'name': 'Montana Bureau of Mines and Geology',
#     'oldPartyId': 18255,
#     'onlineResource': 'http://www.mbmg.mtech.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Butte',
#       'line1': '1300 West Park Street',
#       'state': 'MT',
#       'zip': '59701-8997'},
#      'name': 'Montana Bureau of Mines and Geology',
#      'officePhone': '4064964174',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/MTLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfd2',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfd2'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfd2'}},
#   'spatial': {'boundingBox': {'maxX': -104.039564333,
#     'maxY': 49.001391,
#     'minX': -116.05,
#     'minY': 44.358208667},
#    'representationalPoint': [-110.0447821665, 46.6797998335],
#    'representationalPointIsDerived': True},
#   'title': 'Montana Bureau of Mines and Geology'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NHLogo.gif',
#     'name': 'New Hampshire Geological Survey',
#     'oldPartyId': 18258,
#     'onlineResource': 'http://des.nh.gov/organization/commissioner/gsu/',
#     'primaryLocation': {'mailAddress': {'city': 'Concord',
#       'line1': '29 Hazen Drive; PO Box 95',
#       'state': 'NH',
#       'zip': '03302-0095'},
#      'name': 'New Hampshire Geological Survey',
#      'officePhone': '6032711976',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NHLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfd8',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfd8'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfd8'}},
#   'spatial': {'boundingBox': {'maxX': -70.708399667,
#     'maxY': 45.305472667,
#     'minX': -72.557245,
#     'minY': 42.696982333},
#    'representationalPoint': [-71.6328223335, 44.0012275],
#    'representationalPointIsDerived': True},
#   'title': 'New Hampshire Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'delgeosurvey@udel.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/DELogo.gif',
#     'name': 'Delaware Geological Survey',
#     'oldPartyId': 18244,
#     'onlineResource': 'http://www.dgs.udel.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Newark',
#       'line1': '257 Academy St.',
#       'line2': 'Delaware Geological Survey, University of Delaware',
#       'state': 'DE',
#       'zip': '19716-7501'},
#      'name': 'Delaware Geological Survey - Location',
#      'officePhone': '3028312833',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/DELogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4760e4b07f02db47dfbb',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4760e4b07f02db47dfbb'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4760e4b07f02db47dfbb'}},
#   'spatial': {'boundingBox': {'maxX': -75.048408667,
#     'maxY': 39.839009333,
#     'minX': -75.788754667,
#     'minY': 38.451018},
#    'representationalPoint': [-75.41858166700001, 39.1450136665],
#    'representationalPointIsDerived': True},
#   'title': 'Delaware Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'person',
#     'email': 'lpowers@usgs.gov',
#     'firstName': 'Lindsay',
#     'jobTitle': 'Program Coordinator',
#     'lastName': 'Powers',
#     'middleName': 'A',
#     'name': 'Lindsay A Powers',
#     'oldPartyId': 72626,
#     'orcId': '0000-0001-6743-0820',
#     'organization': {'displayText': 'Data Preservation, Informatics, and Laboratories Program Office'},
#     'primaryLocation': {'building': 'DFC Bldg 810',
#      'buildingCode': 'KBT',
#      'mailAddress': {},
#      'name': 'CN=Lindsay A Powers,OU=CSS,OU=Users,OU=OITS,OU=DI,DC=gs,DC=doi,DC=net - Primary Location',
#      'officePhone': '3032024828',
#      'streetAddress': {'city': 'Lakewood',
#       'country': 'US',
#       'line1': 'W 6th Ave Kipling St',
#       'state': 'CO',
#       'zip': '80225'}},
#     'type': 'Data Owner'},
#    {'active': True,
#     'contactType': 'person',
#     'email': 'nggdpp@usgs.gov',
#     'firstName': 'GS-CSS',
#     'lastName': 'NGGDPP Program',
#     'name': 'GS-CSS NGGDPP Program',
#     'oldPartyId': 64159,
#     'primaryLocation': {'mailAddress': {},
#      'name': 'CN=GS-CSS NGGDPP Program,OU=Shared Mailboxes,OU=Messaging,DC=gs,DC=doi,DC=net - Primary Location',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '5728c7abe4b0b13d3918a960',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/5728c7abe4b0b13d3918a960'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5728c7abe4b0b13d3918a960'}},
#   'spatial': {'boundingBox': {'maxX': 179.775939941213,
#     'maxY': 71.3514404291142,
#     'minX': -178.216552734375,
#     'minY': 18.9254779809854},
#    'representationalPoint': [0.7796936034190054, 45.1384592050498],
#    'representationalPointIsDerived': True},
#   'title': 'U.S. Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'email': 'cgs_pubs@mines.edu',
#     'name': 'Colorado Geological Survey',
#     'oldPartyId': 73928,
#     'onlineResource': 'http://coloradogeologicalsurvey.org',
#     'primaryLocation': {'building': 'Moly Building',
#      'mailAddress': {'city': 'Golden',
#       'line1': '1801 19th Street',
#       'state': 'CO',
#       'zip': '80401'},
#      'name': 'Colorado Geological Survey',
#      'officePhone': '3033842655',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '5a722ec6e4b0a9a2e9de8636',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/5a722ec6e4b0a9a2e9de8636'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5a722ec6e4b0a9a2e9de8636'}},
#   'spatial': {'boundingBox': {'maxX': -102.041481667,
#     'maxY': 41.003445,
#     'minX': -109.060255333,
#     'minY': 36.992427},
#    'representationalPoint': [-105.5508685, 38.997935999999996],
#    'representationalPointIsDerived': True},
#   'title': 'Colorado Geological Survey'},
#  {'contacts': [{'active': True,
#     'aliases': ['NATIONAL ICE CORE LABORATORY',
#      'NICL',
#      'NATIONAL ICE CORE LAB'],
#     'contactType': 'organization',
#     'fbmsCodes': ['GGHCGP0000', 'GGHIEP0000'],
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/USGSLogo.gif',
#     'name': 'National Ice Core Laboratory',
#     'oldPartyId': 17173,
#     'onlineResource': 'http://nicl.usgs.gov/',
#     'primaryLocation': {'building': 'DFC Bldg 810',
#      'buildingCode': 'KBT',
#      'mailAddress': {'city': 'Denver',
#       'country': 'USA',
#       'line1': 'Box 25046',
#       'line2': 'Mailstop 150',
#       'state': 'CO',
#       'zip': '80225-0046'},
#      'name': 'Denver Federal Center - DFC Bldg 810 [KBT]',
#      'shortName': 'DFC, Bldg 810, KBT, MS 150',
#      'streetAddress': {'city': 'Lakewood',
#       'country': 'USA',
#       'line1': 'West 6th Ave. & Kipling St.',
#       'line2': 'DFC Bldg. 810',
#       'state': 'CO',
#       'zip': '80225-0046'}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/USGSLogo.gif',
#     'type': 'Contact'}],
#   'id': '586fd742e4b01a71ba0c5eaa',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/586fd742e4b01a71ba0c5eaa'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=586fd742e4b01a71ba0c5eaa'}},
#   'spatial': {'boundingBox': {'maxX': -105.126928688551,
#     'maxY': 39.7159460129284,
#     'minX': -105.126928688551,
#     'minY': 39.7159460129284},
#    'representationalPoint': [-105.126928688551, 39.7159460129284],
#    'representationalPointIsDerived': True},
#   'title': 'National Ice Core Laboratory (NICL)'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'iihr-iowa-geological-survey@uiowa.edu',
#     'name': 'Iowa Geological Survey',
#     'oldPartyId': 18228,
#     'onlineResource': 'http://www.igsb.uiowa.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Iowa City',
#       'line1': 'Iowa Geological Survey, The University of Iowa',
#       'line2': '300 Trowbridge Hall',
#       'state': 'Iowa',
#       'zip': '52242-1585'},
#      'name': 'Iowa Geological Survey',
#      'officePhone': '3193351575',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfc1',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfc1'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfc1'}},
#   'spatial': {'boundingBox': {'maxX': -90.140064333,
#     'maxY': 43.5012,
#     'minX': -96.639709333,
#     'minY': 40.375435667},
#    'representationalPoint': [-93.38988683299999, 41.938317833499994],
#    'representationalPointIsDerived': True},
#   'title': 'Iowa Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'highlighted': True,
#     'name': 'New Mexico Bureau of Geology and Mineral Resources',
#     'oldPartyId': 18260,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfdc',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfdc'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfdc'}},
#   'spatial': {'boundingBox': {'maxX': -103.001960754395,
#     'maxY': 37.0002937316895,
#     'minX': -109.050178527832,
#     'minY': 31.3321723937988},
#    'representationalPoint': [-106.10634138793651, 34.461499182576624],
#    'representationalPointIsDerived': True},
#   'title': 'New Mexico Bureau of Geology and Mineral Resources'},
#  {'contacts': [{'contactType': 'organization',
#     'name': 'Texas Bureau of Economic Geology',
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dff0',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dff0'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dff0'}},
#   'spatial': {'boundingBox': {'maxX': -93.508127,
#     'maxY': 36.5007,
#     'minX': -106.645644667,
#     'minY': 25.837372667},
#    'representationalPoint': [-100.0768858335, 31.169036333500003],
#    'representationalPointIsDerived': True},
#   'title': 'Texas Bureau of Economic Geology'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'njgsweb@dep.nj.gov',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NJLogo.gif',
#     'name': 'New Jersey Geological and Water Survey',
#     'oldPartyId': 18259,
#     'onlineResource': 'http://www.state.nj.us/dep/njgs/',
#     'primaryLocation': {'mailAddress': {'city': 'Trenton',
#       'line1': 'P. O. Box 420',
#       'line2': 'Mail Code:29-01',
#       'state': 'NJ',
#       'zip': '08625-0420'},
#      'name': 'New Jersey Geological and Water Survey',
#      'officePhone': '6092921185',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NJLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfda',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfda'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfda'}},
#   'spatial': {'boundingBox': {'maxX': -73.893982,
#     'maxY': 41.357427,
#     'minX': -75.559790667,
#     'minY': 38.928518333},
#    'representationalPoint': [-74.7268863335, 40.1429726665],
#    'representationalPointIsDerived': True},
#   'title': 'New Jersey Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'name': 'North Carolina Geological Survey',
#     'oldPartyId': 73930,
#     'onlineResource': 'https://deq.nc.gov/about/divisions/energy-mineral-land-resources/north-carolina-geological-survey',
#     'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#       'line1': '512 North Salisbury Street',
#       'line2': '1612 Mail Service Center',
#       'state': 'NC',
#       'zip': '27699-1612'},
#      'name': 'North Carolina Geological Survey',
#      'officePhone': '9197079210',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '5b6c8f3ce4b006a11f7bd12b',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/5b6c8f3ce4b006a11f7bd12b'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5b6c8f3ce4b006a11f7bd12b'}},
#   'spatial': {'boundingBox': {'maxX': -75.459982,
#     'maxY': 36.588118,
#     'minX': -84.321873,
#     'minY': 33.839809},
#    'representationalPoint': [-79.8909275, 35.213963500000006],
#    'representationalPointIsDerived': True},
#   'title': 'North Carolina Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'ohioseis@dnr.state.oh.us',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/OHLogo.gif',
#     'name': 'Ohio Geological Survey',
#     'oldPartyId': 18263,
#     'onlineResource': 'http://www.ohiodnr.com/geosurvey',
#     'primaryLocation': {'mailAddress': {'city': 'Columbus',
#       'line1': '2045 Morse Rd., Bldg. C-1',
#       'state': 'OH',
#       'zip': '43229-6693'},
#      'name': 'Ohio Department of Natural Resources-Division of Geological Survey - Location',
#      'officePhone': '6142656576',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/OHLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfe6',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfe6'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfe6'}},
#   'spatial': {'boundingBox': {'maxX': -80.518691333,
#     'maxY': 41.977526667,
#     'minX': -84.820209333,
#     'minY': 38.403182333},
#    'representationalPoint': [-82.669450333, 40.1903545],
#    'representationalPointIsDerived': True},
#   'title': 'Ohio Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'scgs@dnr.sc.gov',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/SCLogo.gif',
#     'name': 'South Carolina Geological Survey',
#     'oldPartyId': 18267,
#     'onlineResource': 'http://www.dnr.sc.gov/geology/',
#     'primaryLocation': {'mailAddress': {'city': 'Columbia',
#       'line1': '5 Geology Road',
#       'state': 'SC',
#       'zip': '29212'},
#      'name': 'South Carolina Geological Survey',
#      'officePhone': '8038967931',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/SCLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47e000',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47e000'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47e000'}},
#   'spatial': {'boundingBox': {'maxX': -78.549935667,
#     'maxY': 35.215536,
#     'minX': -83.353955,
#     'minY': 32.047045},
#    'representationalPoint': [-80.95194533349999, 33.6312905],
#    'representationalPointIsDerived': True},
#   'title': 'South Carolina Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NVLogo.gif',
#     'name': 'Nevada Bureau of Mines and Geology',
#     'oldPartyId': 18261,
#     'onlineResource': 'http://www.nbmg.unr.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Reno',
#       'line1': '1664 N Virginia Street',
#       'state': 'NV',
#       'zip': '89557'},
#      'name': 'Nevada Bureau of Mines and Geology - Location',
#      'officePhone': '7757846691',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NVLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfd6',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfd6'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfd6'}},
#   'spatial': {'boundingBox': {'maxX': -114.039645,
#     'maxY': 42.002208667,
#     'minX': -120.005745333,
#     'minY': 35.002082},
#    'representationalPoint': [-117.0226951665, 38.502145333499996],
#    'representationalPointIsDerived': True},
#   'title': 'Nevada Bureau of Mines and Geology'},
#  {'contacts': [{'active': True,
#     'aliases': ['https://geology.utah.gov/'],
#     'contactType': 'organization',
#     'highlighted': True,
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/UTLogo.gif',
#     'name': 'Utah Geological Survey',
#     'oldPartyId': 18269,
#     'onlineResource': 'https://geology.utah.gov/',
#     'primaryLocation': {'building': 'Utah Department of Natural Resources Building',
#      'latitude': 40.772109,
#      'longitude': -111.93656,
#      'mailAddress': {'city': 'Salt Lake City',
#       'line1': 'P.O. Box 146100',
#       'state': 'Utah',
#       'zip': '84114-6100'},
#      'name': 'Utah Geological Survey',
#      'officePhone': '(801) 537-3300',
#      'roomNumber': '3rd Floor',
#      'shortName': 'UGS',
#      'streetAddress': {'city': 'Salt Lake City',
#       'line1': '1594 West North Temple',
#       'state': 'Utah',
#       'zip': '84116'}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/UTLogo.gif',
#     'type': 'Data Owner'},
#    {'company': 'Utah Geological Survey',
#     'contactType': 'person',
#     'email': 'stevebowman@utah.gov',
#     'firstName': 'Steve',
#     'highlighted': True,
#     'jobTitle': 'Geologic Hazards Program Manager',
#     'lastName': 'Bowman',
#     'middleName': 'D.',
#     'name': 'Steve D. Bowman',
#     'organization': {'displayText': 'Utah Geological Survey'},
#     'primaryLocation': {'building': 'Utah Department of Natural Resources Building',
#      'mailAddress': {'city': 'Salt Lake City',
#       'line1': 'P.O. Box 146100',
#       'state': 'Utah',
#       'zip': '84114-6100'},
#      'name': 'Utah Geological Survey',
#      'officePhone': '801-537-3304',
#      'shortName': 'UGS',
#      'streetAddress': {'city': 'Salt Lake City',
#       'line1': '1594 West North Temple',
#       'state': 'Utah',
#       'zip': '84114'}},
#     'type': 'Principal Investigator'}],
#   'id': '4f4e4762e4b07f02db47dff2',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dff2'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dff2'}},
#   'spatial': {'boundingBox': {'maxX': -109.041496276855,
#     'maxY': 42.0017204284668,
#     'minX': -114.052932739258,
#     'minY': 36.9976921081543},
#    'representationalPoint': [-111.68242416448844, 39.36421126009102],
#    'representationalPointIsDerived': True},
#   'title': 'Utah Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/ORLogo.gif',
#     'name': 'Oregon Department of Geology and Mineral Industries',
#     'oldPartyId': 18265,
#     'onlineResource': 'http://www.oregongeology.org/',
#     'primaryLocation': {'mailAddress': {'city': 'Portland',
#       'line1': '800 NE Oregon Street, Suite 965',
#       'state': 'OR',
#       'zip': '97232'},
#      'name': 'Oregon Department of Geology and Mineral Industries',
#      'officePhone': '9716731555',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/ORLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dfea',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dfea'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dfea'}},
#   'spatial': {'boundingBox': {'maxX': -116.463264,
#     'maxY': 46.237318333,
#     'minX': -124.566709,
#     'minY': 41.991791333},
#    'representationalPoint': [-120.51498649999999, 44.114554833],
#    'representationalPointIsDerived': True},
#   'title': 'Oregon Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/AZLogo.gif',
#     'name': 'Arizona Geological Survey',
#     'oldPartyId': 18242,
#     'onlineResource': 'http://www.azgs.az.gov/',
#     'primaryLocation': {'mailAddress': {'city': 'Tucson',
#       'line1': '1955 East Sixth Street',
#       'line2': 'PO Box 210184',
#       'state': 'AZ',
#       'zip': '85721'},
#      'name': 'Arizona Geological Survey - Location',
#      'officePhone': '5206212470',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/AZLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4760e4b07f02db47dfb7',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4760e4b07f02db47dfb7'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4760e4b07f02db47dfb7'}},
#   'spatial': {'boundingBox': {'maxX': -109.045227050781,
#     'maxY': 37.004264831543,
#     'minX': -114.816596984863,
#     'minY': 31.3321800231934},
#    'representationalPoint': [-111.66655592587998, 34.33596489912669],
#    'representationalPointIsDerived': True},
#   'title': 'Arizona Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'description': 'Our mission is to serve the people of Arkansas by providing geological information in order to develop and enable effective management of the State’s mineral, fossil fuel and water resources while protecting the environment. We look forward to working with the public, industry and government in accomplishing our mission goals. Please feel free to call on us with your questions and we will do our utmost to assist you.',
#     'email': 'ags@arkansas.gov',
#     'logoUrl': 'http://www.geology.ar.gov/home/AgsBanner.gif',
#     'name': 'Arkansas Geological Survey',
#     'oldPartyId': 59838,
#     'onlineResource': 'http://www.geology.ar.gov/',
#     'primaryLocation': {'building': 'Vardelle Parham Geology Center',
#      'mailAddress': {'city': 'Little Rock',
#       'line1': '3815 West Roosevelt Road',
#       'state': 'AR',
#       'zip': '72204'},
#      'name': 'Arkansas Geological Survey - Location',
#      'officePhone': '5012961877',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://www.geology.ar.gov/home/AgsBanner.gif',
#     'type': 'Data Owner'}],
#   'id': '4fabfcaee4b07752ae5cf1e3',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4fabfcaee4b07752ae5cf1e3'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4fabfcaee4b07752ae5cf1e3'}},
#   'spatial': {'boundingBox': {'maxX': -89.6448287963867,
#     'maxY': 36.4996109008789,
#     'minX': -94.617919921875,
#     'minY': 33.0041084289551},
#    'representationalPoint': [-92.43738696015566, 34.91724849612706],
#    'representationalPointIsDerived': True},
#   'title': 'Arkansas Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'description': 'The work of the Missouri Department of Natural Resources teaches environmental stewardship and wise use of our precious natural resources through a broad understanding and appreciation for Missouri’s natural, cultural and energy resources.',
#     'email': 'geology@dnr.mo.gov',
#     'logoUrl': 'http://www.dnr.mo.gov/img/logo.jpg',
#     'name': 'Missouri Geological Survey',
#     'oldPartyId': 62230,
#     'onlineResource': 'http://dnr.mo.gov/geology/index.html',
#     'primaryLocation': {'mailAddress': {'city': 'Rolla',
#       'country': 'USA',
#       'line1': 'PO Box 250',
#       'state': 'MO',
#       'zip': '65402-0250'},
#      'name': 'Missouri Geological Survey',
#      'officePhone': '5733682100',
#      'streetAddress': {'city': 'Rolla',
#       'country': 'USA',
#       'line1': '111 Fairgrounds Road',
#       'state': 'MO',
#       'zip': '65402-0250'}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfd0',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfd0'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfd0'}},
#   'spatial': {'boundingBox': {'maxX': -89.098845333,
#     'maxY': 40.613645,
#     'minX': -95.774700333,
#     'minY': 35.995682},
#    'representationalPoint': [-92.43677283299999, 38.304663500000004],
#    'representationalPointIsDerived': True},
#   'title': 'Missouri Geological Survey'},
#  {'contacts': [{'name': 'Minnesota Geological',
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfce',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfce'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfce'}},
#   'spatial': {'boundingBox': {'maxX': -89.483381667,
#     'maxY': 49.384355333,
#     'minX': -97.239209333,
#     'minY': 43.499355333},
#    'representationalPoint': [-93.36129550000001, 46.441855333],
#    'representationalPointIsDerived': True},
#   'title': 'Minnesota Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/PALogo.gif',
#     'name': 'Pennsylvania Geological Survey',
#     'oldPartyId': 18266,
#     'onlineResource': 'http://www.dcnr.state.pa.us/topogeo/',
#     'primaryLocation': {'mailAddress': {'city': 'Pittsburgh',
#       'line1': '400 Waterfront Drive',
#       'state': 'PA',
#       'zip': '15222'},
#      'name': 'Pennsylvania Geological Survey',
#      'officePhone': '4124424235',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/PALogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dfec',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dfec'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dfec'}},
#   'spatial': {'boundingBox': {'maxX': -74.689518333,
#     'maxY': 42.269864333,
#     'minX': -80.519891333,
#     'minY': 39.7198},
#    'representationalPoint': [-77.604704833, 40.994832166500004],
#    'representationalPointIsDerived': True},
#   'title': 'Pennsylvania Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'name': 'Vermont Geological Survey',
#     'oldPartyId': 73927,
#     'onlineResource': 'http://dec.vermont.gov/geological-survey',
#     'primaryLocation': {'mailAddress': {'city': 'Montpelier',
#       'line1': '1 National Life Drive, Main 2',
#       'state': 'VT',
#       'zip': '05620-3902'},
#      'name': 'Vermont Geological Survey',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '52d9aab1e4b08fdd528224a8',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/52d9aab1e4b08fdd528224a8'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=52d9aab1e4b08fdd528224a8'}},
#   'spatial': {'boundingBox': {'maxX': -71.464555333,
#     'maxY': 45.016663667,
#     'minX': -73.437745,
#     'minY': 42.726854667},
#    'representationalPoint': [-72.45115016650001, 43.871759167],
#    'representationalPointIsDerived': True},
#   'title': 'Vermont Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'igsinfo@indiana.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/INLogo.gif',
#     'name': 'Indiana Geological Survey',
#     'oldPartyId': 18247,
#     'onlineResource': 'http://igs.indiana.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Bloomington',
#       'line1': '611 N. Walnut Grove',
#       'state': 'Indiana',
#       'zip': '47405-2208'},
#      'name': 'Indiana Geological Survey - Location',
#      'officePhone': '8128557636',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/INLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfbf',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfbf'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfbf'}},
#   'spatial': {'boundingBox': {'maxX': -84.784581667,
#     'maxY': 41.760691,
#     'minX': -88.097890667,
#     'minY': 37.771745},
#    'representationalPoint': [-86.441236167, 39.766218],
#    'representationalPointIsDerived': True},
#   'title': 'Indiana Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'igs@uidaho.edu',
#     'logoUrl': 'https://www.idahogeology.org/sites/default/files/igs-logo-blue.png',
#     'name': 'Idaho Geological Survey',
#     'oldPartyId': 18236,
#     'onlineResource': 'http://www.idahogeology.org/',
#     'primaryLocation': {'building': 'Morrill Hall, Third Floor',
#      'mailAddress': {'city': 'Moscow',
#       'line1': 'Morrill Hall, Third Floor',
#       'line2': 'University of Idaho',
#       'state': 'ID',
#       'zip': '83844-3014'},
#      'name': 'Idaho Geological Survey - Location',
#      'officePhone': '2088857991',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfbd',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfbd'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfbd'}},
#   'spatial': {'boundingBox': {'maxX': -111.043500333,
#     'maxY': 49.001144667,
#     'minX': -117.243026667,
#     'minY': 41.988009333},
#    'representationalPoint': [-114.14326349999999, 45.494577],
#    'representationalPointIsDerived': True},
#   'title': 'Idaho Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'person',
#     'email': 'michelle.ladle@dep.state.fl.us',
#     'firstName': 'Michelle',
#     'lastName': 'Ladle',
#     'name': 'Michelle Ladle',
#     'oldPartyId': 67591,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Contact'},
#    {'active': True,
#     'contactType': 'organization',
#     'highlighted': True,
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/FLLogo.gif',
#     'name': 'Florida Geological Survey',
#     'oldPartyId': 18245,
#     'onlineResource': 'https://floridadep.gov/fgs',
#     'primaryLocation': {'mailAddress': {'city': 'Tallahassee',
#       'line1': '3000 Commonwealth Blvd., Suite 1',
#       'state': 'FL',
#       'zip': '32303'},
#      'name': 'Florida Geological Survey',
#      'officePhone': '8506170300',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/FLLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfe2',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfe2'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfe2'}},
#   'spatial': {'boundingBox': {'maxX': -80.0313568115234,
#     'maxY': 31.0009727478027,
#     'minX': -87.6349411010742,
#     'minY': 24.5440902709961},
#    'representationalPoint': [-83.8331489562988, 27.7725315093994],
#    'representationalPointIsDerived': True},
#   'title': 'Florida Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NYLogo.gif',
#     'name': 'New York State Geological Survey',
#     'oldPartyId': 18262,
#     'onlineResource': 'http://www.nysm.nysed.gov/research-collections/geology',
#     'primaryLocation': {'mailAddress': {'city': 'Albany',
#       'line1': '222 Madison Avenue',
#       'state': 'NY',
#       'zip': '12230'},
#      'name': 'New York State Geological Survey - Location',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NYLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfde',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfde'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfde'}},
#   'spatial': {'boundingBox': {'maxX': -71.856154667,
#     'maxY': 45.015855,
#     'minX': -79.762155667,
#     'minY': 40.496118333},
#    'representationalPoint': [-75.809155167, 42.7559866665],
#    'representationalPointIsDerived': True},
#   'title': 'New York Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'snrsales@unl.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/NELogo.gif',
#     'name': 'Nebraska Geological Survey',
#     'oldPartyId': 18257,
#     'onlineResource': 'http://snr.unl.edu/csd/surveyareas/geology.asp',
#     'primaryLocation': {'mailAddress': {'city': 'Lincoln',
#       'line1': '3310 Holdrege Street',
#       'state': 'NE',
#       'zip': '68583-0961'},
#      'name': 'Nebraska Geological Survey',
#      'officePhone': '4024723471',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/NELogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfd4',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfd4'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfd4'}},
#   'spatial': {'boundingBox': {'maxX': -95.308291,
#     'maxY': 43.001709,
#     'minX': -104.053518333,
#     'minY': 40},
#    'representationalPoint': [-99.6809046665, 41.5008545],
#    'representationalPointIsDerived': True},
#   'title': 'Nebraska Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'email': 'info@gsa.state.al.us',
#     'highlighted': True,
#     'name': 'Geological Survey of Alabama',
#     'oldPartyId': 18240,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47e004',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47e004'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47e004'}},
#   'spatial': {'boundingBox': {'maxX': -84.888244667,
#     'maxY': 35.008026667,
#     'minX': -88.473226667,
#     'minY': 30.220855},
#    'representationalPoint': [-86.680735667, 32.6144408335],
#    'representationalPointIsDerived': True},
#   'title': 'Geological Survey of Alabama'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'ogsweb@ou.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/OKLogo.gif',
#     'name': 'Oklahoma Geological Survey',
#     'oldPartyId': 18264,
#     'onlineResource': 'http://www.ogs.ou.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Norman',
#       'line1': '100 E. Boyd St., Suite N131',
#       'state': 'OK',
#       'zip': '73019'},
#      'name': 'Oklahoma Geological Survey',
#      'officePhone': '4053253031',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/OKLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dfe8',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dfe8'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dfe8'}},
#   'spatial': {'boundingBox': {'maxX': -94.431218,
#     'maxY': 37.002327333,
#     'minX': -103.002645333,
#     'minY': 33.615764333},
#    'representationalPoint': [-98.7169316665, 35.309045833],
#    'representationalPointIsDerived': True},
#   'title': 'Oklahoma Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'rpaulsell@lsu.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/LAlogo.gif',
#     'name': 'Louisiana Geological Survey',
#     'oldPartyId': 18248,
#     'onlineResource': 'http://www.lgs.lsu.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Baton Rouge',
#       'line1': '3079 Energy, Coastal and Environment Building',
#       'state': 'LA',
#       'zip': '70803'},
#      'name': 'Louisiana Geological Survey',
#      'officePhone': '2255785320',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/LAlogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfc5',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfc5'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfc5'}},
#   'spatial': {'boundingBox': {'maxX': -88.816517667,
#     'maxY': 33.019545333,
#     'minX': -94.043345333,
#     'minY': 28.926455333},
#    'representationalPoint': [-91.42993150000001, 30.973000333],
#    'representationalPointIsDerived': True},
#   'title': 'Louisiana Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'webadmin@kgs.ku.edu',
#     'name': 'Kansas Geological Survey',
#     'oldPartyId': 18235,
#     'onlineResource': 'http://www.kgs.ku.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Lawrence',
#       'line1': '1930 Constant Avenue',
#       'state': 'KS',
#       'zip': '66047-3724'},
#      'name': 'Kansas Geological Survey',
#      'officePhone': '7858643965',
#      'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfc3',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfc3'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfc3'}},
#   'spatial': {'boundingBox': {'maxX': -94.589935667,
#     'maxY': 40.003164333,
#     'minX': -102.051773333,
#     'minY': 36.993082},
#    'representationalPoint': [-98.3208545, 38.4981231665],
#    'representationalPointIsDerived': True},
#   'title': 'Kansas Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/MALogo.gif',
#     'name': 'Massachusetts Geological Survey',
#     'oldPartyId': 18249,
#     'onlineResource': 'http://mgs.geo.umass.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Amherst',
#       'line1': 'Department of Geosciences, 269 Morrill Science Center',
#       'line2': 'University of Massachusetts, 611 North Pleasant Street',
#       'state': 'MA',
#       'zip': '01003-9297'},
#      'name': 'Massachusetts Geological Survey - Location',
#      'officePhone': '4135454814',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/MALogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfe4',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfe4'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfe4'}},
#   'spatial': {'boundingBox': {'maxX': -69.927800333,
#     'maxY': 42.886791333,
#     'minX': -73.508145333,
#     'minY': 41.237964333},
#    'representationalPoint': [-71.717972833, 42.062377833],
#    'representationalPointIsDerived': True},
#   'title': 'Massachusetts Geological Survey'},
#  {'contacts': [{'contactType': 'person',
#     'name': 'Archivist, 3817 Mineral Point Road, Madison, WI  (608)262 1705',
#     'onlineResource': 'http://wgnhs.uwex.edu/',
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'ttyPhone': '608 262 1705',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dffa',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dffa'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dffa'}},
#   'spatial': {'boundingBox': {'maxX': -86.805191,
#     'maxY': 47.003381667,
#     'minX': -92.889435667,
#     'minY': 42.491817667},
#    'representationalPoint': [-89.8473133335, 44.747599667],
#    'representationalPointIsDerived': True},
#   'title': 'Wisconsin Geological Survey'},
#  {'contacts': [{'contactType': 'organization',
#     'name': 'Washington Geological Survey',
#     'oldPartyId': 18272,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'},
#    {'contactType': 'person',
#     'name': 'Robert Berwick',
#     'oldPartyId': 15474,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}}}],
#   'id': '4f4e4762e4b07f02db47dff6',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dff6'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dff6'}},
#   'spatial': {'boundingBox': {'maxX': -116.915580749512,
#     'maxY': 49.0024948120117,
#     'minX': -124.733177185059,
#     'minY': 45.5435409545898}},
#   'title': 'Washington Geological Survey'},
#  {'contacts': [{'company': 'VA DMME',
#     'contactType': 'person',
#     'email': 'Chrissi.Wood-Smith@dmme.virginia.gov',
#     'firstName': 'Chrissi',
#     'lastName': 'Wood-Smith',
#     'middleName': 'M',
#     'name': 'Christina Wood-Smith',
#     'primaryLocation': {'mailAddress': {},
#      'streetAddress': {'city': 'Charlottesville',
#       'line1': '900 Natural Resouces Dr',
#       'line2': 'Ste 200',
#       'state': 'VA',
#       'zip': '22903'}},
#     'ttyPhone': '434-951-6322',
#     'type': 'Principal Investigator'},
#    {'name': 'Division of Geology and Mineral Resources',
#     'primaryLocation': {'faxPhone': '4349516325',
#      'mailAddress': {},
#      'streetAddress': {'city': 'Charlottesville',
#       'line1': '900 Natural Resources Dr',
#       'line2': 'Ste 200',
#       'state': 'VA',
#       'zip': '22903'}},
#     'ttyPhone': '4349516340',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dff4',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dff4'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dff4'}},
#   'spatial': {'boundingBox': {'maxX': -75.2422637939453,
#     'maxY': 39.4660110473633,
#     'minX': -83.6754150390625,
#     'minY': 36.5407333374023},
#    'representationalPoint': [-79.4588394165039, 38.0033721923828],
#    'representationalPointIsDerived': True},
#   'title': 'Virginia Division of Geology and Mineral Resources'},
#  {'contacts': [{'contactType': 'organization',
#     'name': 'Geological and Natural History Survey of Connecticut',
#     'oldPartyId': 18243,
#     'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dffc',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dffc'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dffc'}},
#   'spatial': {'boundingBox': {'maxX': -71.7869873046875,
#     'maxY': 42.050594329834,
#     'minX': -73.7277755737305,
#     'minY': 40.9865989685059}},
#   'title': 'Connecticut Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'info@isgs.illinois.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/ILLogo.gif',
#     'name': 'Illinois State Geological Survey',
#     'oldPartyId': 18246,
#     'onlineResource': 'http://www.isgs.illinois.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Champaign',
#       'line1': '615 E. Peabody Drive',
#       'state': 'Illinois',
#       'zip': '61820'},
#      'name': 'Illinois State Geological Survey',
#      'officePhone': '2173334747',
#      'shortName': 'ISGS',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/ILLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dffe',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dffe'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dffe'}},
#   'spatial': {'boundingBox': {'maxX': -87.4952,
#     'maxY': 42.5083,
#     'minX': -91.513082,
#     'minY': 36.970299667},
#    'representationalPoint': [-89.504141, 39.7392998335],
#    'representationalPointIsDerived': True},
#   'title': 'Illinois Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/MILogo.gif',
#     'name': 'Michigan Geological Survey',
#     'oldPartyId': 18252,
#     'onlineResource': 'https://wmich.edu/geologysurvey',
#     'primaryLocation': {'building': '1184 Rood Hall, Mail Stop 5731',
#      'mailAddress': {'city': 'Kalamazoo',
#       'line1': '1903 W Michigan Ave',
#       'state': 'MI',
#       'zip': '49008-5241'},
#      'name': 'Michigan Geological Survey',
#      'officePhone': '2693875840',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/MILogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfcc',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfcc'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfcc'}},
#   'spatial': {'boundingBox': {'maxX': -82.4186,
#     'maxY': 48.190972667,
#     'minX': -90.418136333,
#     'minY': 41.696091333},
#    'representationalPoint': [-86.4183681665, 44.943532],
#    'representationalPointIsDerived': True},
#   'title': 'Michigan Geological Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'person',
#     'email': 'bbuczkowski@usgs.gov',
#     'firstName': 'Brian',
#     'jobTitle': 'Physical Scientist',
#     'lastName': 'Buczkowski',
#     'name': 'Brian Buczkowski',
#     'oldPartyId': 1316,
#     'organization': {'displayText': 'Woods Hole Coastal and Marine Science Center'},
#     'primaryLocation': {'building': 'Gosnold Building',
#      'buildingCode': 'AGD',
#      'faxPhone': '5084572310',
#      'mailAddress': {'city': 'Woods Hole',
#       'country': 'USA',
#       'line1': '384 Woods Hole Road',
#       'state': 'MA',
#       'zip': '02543-1598'},
#      'name': 'Brian Buczkowski/GD/USGS/DOI - Primary Location',
#      'officePhone': '5084572361',
#      'streetAddress': {'city': 'Woods Hole',
#       'line1': '384 Woods Hole Road',
#       'state': 'MA',
#       'zip': '02543'}},
#     'type': 'Contact'}],
#   'id': '5873c9f2e4b0a829a31e31e9',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/5873c9f2e4b0a829a31e31e9'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5873c9f2e4b0a829a31e31e9'}},
#   'spatial': {'boundingBox': {'maxX': -70.6510067218915,
#     'maxY': 41.5421593464619,
#     'minX': -70.6510067218915,
#     'minY': 41.5421593464619},
#    'representationalPoint': [-70.6510067218915, 41.5421593464619],
#    'representationalPointIsDerived': True},
#   'title': 'USGS Woods Hole Coastal and Marine Science Center Samples Repository'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'email': 'info@geosrv.wvnet.edu',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/WVLogo.gif',
#     'name': 'West Virginia Geological and Economic Survey',
#     'oldPartyId': 18273,
#     'onlineResource': 'http://www.wvgs.wvnet.edu/',
#     'primaryLocation': {'mailAddress': {'city': 'Morgantown',
#       'line1': '1 Mont Chateau Road',
#       'state': 'WV',
#       'zip': '26508-8079'},
#      'name': 'West Virginia Geological and Economic Survey',
#      'officePhone': '3045942331',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/WVLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4762e4b07f02db47dff8',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dff8'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4762e4b07f02db47dff8'}},
#   'spatial': {'boundingBox': {'maxX': -77.719027333,
#     'maxY': 40.6388,
#     'minX': -82.644736333,
#     'minY': 37.201481667},
#    'representationalPoint': [-80.181881833, 38.9201408335],
#    'representationalPointIsDerived': True},
#   'title': 'West Virginia Geological and Economic Survey'},
#  {'contacts': [{'active': True,
#     'contactType': 'organization',
#     'logoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosMed/MDLogo.gif',
#     'name': 'Maryland Geological Survey',
#     'oldPartyId': 18250,
#     'onlineResource': 'http://www.mgs.md.gov/',
#     'primaryLocation': {'mailAddress': {'city': 'Baltimore',
#       'line1': '2300 St. Paul Street',
#       'state': 'Maryland',
#       'zip': '21218'},
#      'name': 'Maryland Geological Survey',
#      'officePhone': '4105545500',
#      'streetAddress': {}},
#     'smallLogoUrl': 'http://my.usgs.gov/static-cache/images/dataOwner/v1/logosSmall/MDLogo.gif',
#     'type': 'Data Owner'}],
#   'id': '4f4e4761e4b07f02db47dfca',
#   'link': {'rel': 'self',
#    'url': 'https://www.sciencebase.gov/catalog/item/4f4e4761e4b07f02db47dfca'},
#   'relatedItems': {'link': {'rel': 'related',
#     'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=4f4e4761e4b07f02db47dfca'}},
#   'spatial': {'boundingBox': {'maxX': -75.048935667,
#     'maxY': 39.723044667,
#     'minX': -79.487655333,
#     'minY': 37.923836333},
#    'representationalPoint': [-77.2682955, 38.823440500000004],
#    'representationalPointIsDerived': True},
#   'title': 'Maryland Geological Survey'}]

# %% [markdown]
# # Collections
#
# The real meat of this work will be in the collection items.

# %%
tag_scheme_collections = next(({'name':ts['name'],'scheme':ts['scheme']} for ts in item_types if ts['name'] == 'ndc_collection'), None)
fields_collections = 'title,files,webLinks,hasChildren,facets,tags'
sb_query_collections = f'{queryRoot}fields={fields_collections}&folderId={parentId}&filter=tags%3D{tag_scheme_collections}'
print(sb_query_collections)
# Out:
# https://www.sciencebase.gov/catalog/items?format=json&max=1000&fields=title,files,webLinks,hasChildren,facets,tags&folderId=4f4e4760e4b07f02db47dfb4&filter=tags%3D{'name': 'ndc_collection', 'scheme': 'https://www.sciencebase.gov/vocab/category/NGGDPP/nggdpp_collection_types'}

# %%
r_ndc_collections = requests.get(sb_query_collections).json()

# %% [markdown]
# I'll be lazy for right now and leave off building a paginated method of working through collection items since there are just under the upper limit of 1,000 items that can be retrieved from ScienceBase in a single query.

# %%
print(len(r_ndc_collections['items']))
# Out:
# 972

# %% [markdown]
# ## Collections with Child Items
#
# First, we can presume at the moment that all collection items that have children currently are the collection items that we should find some type of processable file or WAF link. I know that there are some exceptions to this rule, and this exploration is designed to help delineate those issues for further work. I'll work through this somewhat backwards in terms of identifying the collections that are special cases.

# %% [markdown]
# ### No files and no weblinks
#
# How did these collections get populated? These are a little bit mysterious, but we'll probably need to either track down a new source for these records or else generate something like a GeoJSON structure with point geometry and a set of the essential properties from the ScienceBase Items, stash that file on the items, and then write a processor for those.

# %%
collections_populated_nofiles_noweblinks = [c for c in r_ndc_collections['items'] if c['hasChildren'] and 'files' not in c.keys() and 'webLinks' not in c.keys()]

for collection in collections_populated_nofiles_noweblinks:
    print(collection['title'])
    print(collection['link']['url'])
    print('--------')

print('Total:', len(collections_populated_nofiles_noweblinks))
# Out:
# Collection of Scanned Bedrock Geologic Paper Maps
# https://www.sciencebase.gov/catalog/item/57a9f3fde4b05e859be05d7b
# --------
# Collection of Scanned Surficial Geologic Paper Maps
# https://www.sciencebase.gov/catalog/item/57aa0a62e4b05e859be06621
# --------
# Collection of Rock cores from MO
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df330
# --------
# Rock Thin Sections Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e88
# --------
# Total: 4

# %% [markdown]
# ### No files but do have web links
#
# Next are collections that do not have files attached but do have web links. For the most part, these should be items with web accessible folder references that can be harvested.
#
# But wait...
#
# Only a couple of these actually have WAF URLs specified, so it looks like there are some other mystery items we'll need to clean up.

# %%
collections_populated_nofiles_weblinks = [c for c in r_ndc_collections['items'] if c['hasChildren'] and 'files' not in c.keys() and 'webLinks' in c.keys()]

for collection in collections_populated_nofiles_weblinks:
    waf_url = next((l['uri'] for l in collection['webLinks'] if l['type'] == 'WAF'), None)
    print(collection['title'])
    print(collection['link']['url'])
    print('WAF URL', waf_url)
    print('--------')

print('Total:', len(collections_populated_nofiles_weblinks))
# Out:
# Collection of well construction reports from Wisconsin
# https://www.sciencebase.gov/catalog/item/4f4e4839e4b07f02db4efed3
# WAF URL None
# --------
# Collection of thin sections and polished sections from Wisconsin
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df131
# WAF URL None
# --------
# Collection of rock cores from Wisconsin
# https://www.sciencebase.gov/catalog/item/4f4e4b18e4b07f02db6a6ff8
# WAF URL None
# --------
# Collection of field notes from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df141
# WAF URL None
# --------
# Collection of sediment samples from Wisconsin
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df159
# WAF URL None
# --------
# Arizona Department of Mines and Mineral Resources Photo Archive
# https://www.sciencebase.gov/catalog/item/5009bd91e4b0612f70e97a96
# WAF URL http://repository.stategeothermaldata.org/resources/metadata/DataPres2012-13MineFileInventory/ADMMR_PhotosA-Z/
# --------
# Collection of Borehole geophysical logs from MN
# https://www.sciencebase.gov/catalog/item/5bc0f6e1e4b0fc368eb70156
# WAF URL None
# --------
# Collection of Chevron rock cores
# https://www.sciencebase.gov/catalog/item/52f3d4afe4b0b03a191d4b9b
# WAF URL None
# --------
# Wisconsin GS Lake Superior legacy collection of field notebooks and ledgers
# https://www.sciencebase.gov/catalog/item/5684316ae4b0a04ef4933114
# WAF URL None
# --------
# Index of Scanned Missouri Geological Field Notebooks
# https://www.sciencebase.gov/catalog/item/5060cc39e4b00fc20c4f3dd7
# WAF URL None
# --------
# Collection of rock cores from Wisconsin - Flambeau Mine
# https://www.sciencebase.gov/catalog/item/57bf46b3e4b0f2f0ceb75a83
# WAF URL None
# --------
# Geoscience collections harvested from the Alaska Division of Geological and Geophysical Surveys
# https://www.sciencebase.gov/catalog/item/5141e4c2e4b0eefcba208e52
# WAF URL http://www.dggs.alaska.gov/metadata/
# --------
# Collection of Drill hole cuttings from Missouri
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d910e
# WAF URL None
# --------
# A. F. Budge mining collection
# https://www.sciencebase.gov/catalog/item/57520032e4b053f0edd03e54
# WAF URL http://repository.stategeothermaldata.org/resources/metadata/DataPres2014-2015MineFileInventory/BudgeToUsgin/
# --------
# Collection of Rock Cuttings from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d0e4b07f02db5db529
# WAF URL None
# --------
# Arizona Department of Mines and Mineral Resources mining collection
# https://www.sciencebase.gov/catalog/item/50636a07e4b0a82e8b3d1dae
# WAF URL http://repository.stategeothermaldata.org/resources/metadata/DataPres2012-13MineFileInventory/ADMMR_MineFiles_A-Z/
# --------
# Arizona Department of Mines and Mineral Resources Maps collection
# https://www.sciencebase.gov/catalog/item/511ab167e4b084e2824d6a18
# WAF URL http://repository.stategeothermaldata.org/resources/metadata/DataPres2012-13MineFileInventory/MapColl_425-670V5/
# --------
# List of Missouri Geological Field Notebooks
# https://www.sciencebase.gov/catalog/item/5060af7ae4b00fc20c4f3c84
# WAF URL None
# --------
# Doug Rankin Legacy Geologic Maps
# https://www.sciencebase.gov/catalog/item/59234e52e4b0b7ff9fb11f54
# WAF URL None
# --------
# Wisconsin GS Lake Superior legacy collection of hand samples and thin sections
# https://www.sciencebase.gov/catalog/item/5066142fe4b053bff18e1bd0
# WAF URL None
# --------
# Total: 20

# %% [markdown]
# ### Now for the majority of items with files
# For collections that have only a single processable file, the route we'll take will be pretty straightforward. The one onboard file should be the one that we need to grab up into the index for that collection. A challenge we're going to have, though, is that quite a number of these collections have more than one file onboard. There are cases where data owners are actively maintaining their collections either in the ScienceBase interface or through the NDC Dashboard app, loading up different versions of files over time and processing them to generate child items in the current architecture. In other cases, it appears that USGS staff helped data providers along by modifying original source files and setting those up to be loaded, leaving both the original file and a modified file on board the items. In some cases, it appears that the number of collection items was high enough that data owners split them up into multiple files.
#
# From a data management perspective, it's great that data owners and USGS support staff keep all versions of files in the repository. However, there is not a clear way to always identify the correct files to process that represent the current inventory for a given collection. We can't really use the data/time stamp for when files were modified or user IDs of the user who uploaded the files to tease this out, because we don't really know the sequence of events. I took a look at using the "processed" flag, which is a ScienceBase-specific thing indicating that the file was run through the process to put its records into child items. However, that doesn't really do anything for us either since there is still no indication of which process was run last.
#
# In other use cases, we've used the title property in the file object part of the ScienceBase Item model to store a text string indicating the purpose of a given file. This is really the only property that can be manipulated in the system, other than some type of file name convention, which is a losing proposition given the varied ways people have of using file naming in their own processes. The other option would be to include some type of manifest as a separate file that provides essentially a little bit of additional metadata for every file attached to a collection. Either one of these approaches could work programmatically but comes with other issues in terms of sustaining and scaling the method. There are also cases like [this one](https://www.sciencebase.gov/catalog/item/5be068b7e4b0b3fc5cf33543) where data owners have already used the title property to provide other information that still doesn't unambiguously indicate file purpose but probably shouldn't be messed with. Some form of external manifest, entity/attribute, or lookup function is likely the way I'll need to go to determine what to process in collections across the board.
#
# The NDC Dashboard, if that were the only way of maintaining the NDC, would provide the necessary layer of abstraction to impose business rules on how ScienceBase operates in this case. The upload app built into the NDC Dashboard could be tailored to flag files for processing, giving users options such as uploading batches of files, designating that new files should replace old ones, or other necessary dynamics. These processes could result in either files being flagged in a particular way in the ScienceBase Item model or some type of manifest being maintained to be consulted for file purpose.
#
# Another approach could be to move the file management aspect of the NDC into a different type of file management platform that would support actual versioning and more robust ways of providing file-specific metadata. There is, reportedly, a new sbFiles component being developed for ScienceBase that might provide some options, or collection items could reference a third party file management solution via a web link or some other means.
#
# The following crude listing runs through all collection items that have current child items in ScienceBase and do have files on board, and lists the number of files by content type. My next step will be to start winnowing this down to determine as many processable files as I can and then get to a more tractable list of those cases where we will likely need to do some additional sleuthing to determine what to process. I think I can reasonably add some titles to onboard files when their purpose is clear to help narrowing the field. I can at least "set aside" the "metadata.xml" files that were part of the original collection survey information, and I may be able to verify that the single-file cases correspond to the appropriate records for some collections.
#
# I'll then come back and revisit this to provide a more robust report.

# %%
collections_populated_files = [c for c in r_ndc_collections['items'] if c['hasChildren'] and 'files' in c.keys()]

for collection in collections_populated_files:
    files_by_type = {}
    # Ugly loop here but actually seems the cheapest way of doing this after looking at itertools methods
    for f in collection['files']:
        if f['contentType'] not in files_by_type.keys():
            files_by_type[f['contentType']] = [f['name']]
        else:
            files_by_type[f['contentType']].append(f['name'])
    print(collection['title'])
    print(collection['link']['url'])
    
    # Now that we flagged the metadata.xml files, we can get those out of the way as irrelevant in this exercise
    try:
        files_by_type['application/xml'].remove('metadata.xml')
    except:
        pass
    
    for k,v in files_by_type.items():
        if len(v) > 0:
            print(k, " - ", len(v))
        if len(v) > 1:
            print(v)
    print('==================')

print('Total:', len(collections_populated_files))
# Out:
# Anderson Mine collection
# https://www.sciencebase.gov/catalog/item/504f6057e4b03f3ccc029062
# text/plain; charset=windows-1252  -  1
# ==================
# W. H. Crutchfield, Jr. mining collection
# https://www.sciencebase.gov/catalog/item/502e9777e4b0ca196f3915cd
# text/plain; charset=windows-1252  -  1
# ==================
# Kelsey Boltz mining collection inventory
# https://www.sciencebase.gov/catalog/item/505b5f6ae4b08c986b30c279
# text/plain; charset=windows-1252  -  1
# ==================
# Montana Mining Property File Collection
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1b1
# text/csv  -  1
# ==================
# Meredith Johnson, Former State Geologist, Field Notes
# https://www.sciencebase.gov/catalog/item/5775405fe4b07dd077c70874
# text/csv  -  1
# ==================
# Minerals commodities books
# https://www.sciencebase.gov/catalog/item/57755b2ce4b07dd077c708dd
# text/csv  -  1
# ==================
# Collection of Rock cores from Connecticut
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da90e
# text/plain  -  4
# ['06_112941_CTmetadataCSV.csv', '07_114830_CTmetadataCSV.csv', '14_141856_CTmetadataCSV.csv', '14_142338_CTmetadataCSV.csv']
# ==================
# Thin Sections Scans donated by Adam Smith
# https://www.sciencebase.gov/catalog/item/5bd9e3bae4b0b3fc5cebf246
# text/csv  -  1
# ==================
# Connecticut Quaternary and Surficial Geology Quadrangle
# https://www.sciencebase.gov/catalog/item/5228d413e4b06291bed806d4
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Brine Analyses from Kentucky Oil and Gas Wells
# https://www.sciencebase.gov/catalog/item/586fc0c3e4b01a71ba0bc9bc
# application/xml  -  1
# ==================
# Historical Aerial Photographs of Maryland, 1988-1989, Quad-Based Infrared Collection
# https://www.sciencebase.gov/catalog/item/55df7430e4b0518e354e0b67
# text/csv  -  1
# ==================
# Historical Aerial Photographs of Washington, D.C., MD, and VA, 1935-1939 and ca. 1950 Collection
# https://www.sciencebase.gov/catalog/item/55e35a3fe4b05561fa2081f9
# text/csv  -  1
# ==================
# Thin and polished sections
# https://www.sciencebase.gov/catalog/item/5be068b7e4b0b3fc5cf33543
# text/csv  -  9
# ['Colfax.csv', 'Mora.csv', 'Curry.csv', 'Guadalupe.csv', 'Guadalupe_2.csv', 'DeBaca1.csv', 'Harding.csv', 'Quay.csv', 'Union.csv']
# ==================
# Uranium logs of New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49cbe4b07f02db5d8760
# text/plain; charset=windows-1252  -  2
# ['25_145404_P746_UraniumLogs.csv', '20090730_092551_P746_NMUraniuma.csv']
# ==================
# Collection of Geologic Paper Reports from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df299
# text/csv  -  1
# ==================
# UGS UCRC Thin and Polished Section Collection
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df321
# text/html  -  1
# ==================
# Collection of rock cuttings from Washington State
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df24a
# application/xml  -  1
# ==================
# Collection of Sidewall cores from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d917a
# text/plain; charset=windows-1252  -  10
# ['25_135907_P1100_SWC.csv', '25_140035_P1100_SWC.txt', '25_140214_P1100_SWC.csv', '25_140518_P1100_SWC.csv', '25_140759_P1100_SWC.csv', '25_141047_P1100_SWC.csv', '25_143311_P1100_SWC.csv', '25_143400_P1100_SWC.csv', '25_145613_P1100_SWC.csv', '20090925_103439_NM_P1100_NMSWC_Fixed.csv']
# ==================
# Petroleum well history reports for New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df12f
# text/plain  -  1
# ==================
# Coalbed Methane Desorption Data from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df160
# text/plain  -  1
# ==================
# Collection of Groundwater Potential Reports from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2bf
# application/xml  -  1
# ==================
# Collection of paleontological samples from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1cc
# application/xml  -  4
# ['14_124537_UL_5035817_20100714.xml', '09_092916_UL_5035817_20100609.xml', '20110805_150610_UL_5035817_20110805.xml', '20090917_075725_UL_5035817_20090916.xml']
# ==================
# Collection of Thin sections and polished sections from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2c5
# application/xml  -  2
# ['UL_5035827_20121129.xml', 'UL_5035827_20130927.xml']
# ==================
# Rich Volkert, Former Geologist, Field Notes
# https://www.sciencebase.gov/catalog/item/57755d31e4b07dd077c708f6
# text/csv  -  1
# ==================
# Collection of well logs from Washington State
# https://www.sciencebase.gov/catalog/item/4f4e48c5e4b07f02db53f51c
# text/csv  -  2
# ['wa_well_logs_20180720_reformatted.csv', 'wa_well_logs_20180720_reformatted_part2.csv']
# ==================
# Borehole Maps and Logs Created During Interstate 80 Construction
# https://www.sciencebase.gov/catalog/item/5b1a9fd0e4b092d965251a27
# text/csv  -  1
# ==================
# Oil and Gas Well Cuttings from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e9a
# application/xml  -  1
# ==================
# Historic Photographs Collection from Virginia
# https://www.sciencebase.gov/catalog/item/4f4e4a22e4b07f02db60cdf0
# application/xml  -  1
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  2
# ['HistoricPhotosDataDictionary.xlsx', 'HistoricPhotos.xlsx']
# image/jpeg  -  1
# text/csv  -  1
# ==================
# Unpublished Geologic Map Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e5c
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# text/csv  -  2
# ['FieldMaps.csv', 'FieldMaps_edit.csv']
# application/vnd.ms-excel  -  1
# image/jpeg  -  1
# ==================
# USGS Core Research Center (CRC) Collection of Core
# https://www.sciencebase.gov/catalog/item/4f4e49dae4b07f02db5e0486
# application/fgdc+xml  -  1
# ==================
# Collection of Core Analyses from Kentucky Oil and Gas Wells
# https://www.sciencebase.gov/catalog/item/586fc480e4b01a71ba0bc9d3
# application/xml  -  1
# ==================
# Collection of Well logs from New Jersey
# https://www.sciencebase.gov/catalog/item/4f4e49cae4b07f02db5d7db8
# application/xml  -  1
# ==================
# Richard Hahman mining collection
# https://www.sciencebase.gov/catalog/item/502e8c12e4b0ca196f38ec95
# text/plain; charset=windows-1252  -  1
# ==================
# Cambior Exploration USA Inc. mining collection
# https://www.sciencebase.gov/catalog/item/4feca35be4b096ee0d5e044f
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Field Photographs from Alaska
# https://www.sciencebase.gov/catalog/item/55ce5b1ee4b01487cbfc7104
# application/xml  -  1
# ==================
# Collection of annual mining industry reviews from Idaho
# https://www.sciencebase.gov/catalog/item/598a3664e4b09fa1cb0cce3b
# text/csv  -  1
# ==================
# Collection of geologic maps from Louisiana
# https://www.sciencebase.gov/catalog/item/4f4e4814e4b07f02db4db032
# text/plain; charset=windows-1252  -  5
# ['20110729_150328_LGS_Map_Collection2011_Submission_Final.csv', 'LGS_Map_Collection2012_Submission_Final_2_original.csv', 'LGS_Map_Collection2012_Submission_Final_2_forScienceBase.csv', 'LGS_Map_Collection2014_Submission_original.csv', 'LGS_Map_Collection2014_Submission_forScienceBase.csv']
# ==================
# Collection of Geochemical Samples from Michigan
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3de
# text/csv  -  1
# ==================
# Collection of Paleontological samples from Michigan
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df288
# text/plain; charset=windows-1252  -  2
# ['20090918_144810_P1403.csv', '20090925_160133_P1403CSVOGS.csv']
# ==================
# Collection of Field Notes and Unpublished Maps from Alaska
# https://www.sciencebase.gov/catalog/item/57bb5f55e4b03fd6b7dd0532
# application/xml  -  1
# text/csv  -  1
# ==================
# Historical (1948-1977) Photographs of Tidal Shorelines, Maryland
# https://www.sciencebase.gov/catalog/item/4f4e4a94e4b07f02db658da3
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Coal Exploration Records from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e49f2e4b07f02db5ef1cb
# application/xml  -  1
# ==================
# Collection of Geologic Thin Sections and Polished Sections from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da9de
# application/xml  -  2
# ['20091012_103056_thin_sections.xml', '20101112_091247_thin_sections.xml']
# ==================
# Cuttings from drill holes located in New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d8f07
# text/plain; charset=windows-1252  -  1
# text/plain; charset=ISO-8859-1  -  1
# ==================
# Collection of geochemical data from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df14d
# application/xml  -  1
# ==================
# Neil Wills Scout tickets for Drill holes in New Mexico and Texas
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df290
# text/csv  -  3
# ['P750_NeilWills_delim.csv', '20160711_P750_NeilWills.csv', '20160713_P750_NeilWills.csv']
# ==================
# Micropaleontologic (Fusulind) Data from New Mexico drill holes
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df12e
# text/plain  -  1
# ==================
# Collection of Coal Field Measured Sections from Tennessee
# https://www.sciencebase.gov/catalog/item/4f4e4aaae4b07f02db66936f
# text/csv  -  1
# ==================
# Collection of Getty - Mount Chase rock cores
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df227
# ==================
# Collection of Cores and Sediment Grab Samples collected from Maryland Chesapeake Bay and Tributaries
# https://www.sciencebase.gov/catalog/item/4f4e4a94e4b07f02db658d93
# text/plain  -  1
# ==================
# Collection of geophysical data from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df14c
# application/xml  -  1
# ==================
# New Mexico Source-rock analysis
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1f3
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Auger Samples from Wells Drilled in the Jackson Purchase Region of Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a55
# application/xml  -  1
# ==================
# Eastern Gas Shales Publications from the US Department of Energy
# https://www.sciencebase.gov/catalog/item/586fb17ee4b01a71ba0bc974
# application/xml  -  1
# ==================
# Collection of Mineral Property Files from Idaho
# https://www.sciencebase.gov/catalog/item/5600577fe4b05d6c4e5045bf
# text/csv  -  1
# ==================
# Geologic Field Notes from New Jersey
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df38a
# text/plain; charset=windows-1252  -  3
# ['Metadata Christy Bell Card Collection1.csv', 'Field Notebooks Collection Metadata 2.csv', 'Permanent Notes Collection Metadata 2 Revised.csv']
# ==================
# Rich Volkert, Former Geologist, Station Points
# https://www.sciencebase.gov/catalog/item/57755e5ee4b07dd077c7093f
# text/csv  -  1
# ==================
# Unpublished Surficial Geology Quadrangle Maps
# https://www.sciencebase.gov/catalog/item/52caf61de4b017ba5c69d147
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Scout Tickets from Michigan
# https://www.sciencebase.gov/catalog/item/537b6e28e4b0929ba496abf2
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Documents from the Lead-Zinc District of Northwestern Illinois
# https://www.sciencebase.gov/catalog/item/55f98b08e4b05d6c4e50142d
# application/xml  -  1
# ==================
# Historical Aerial Photographs of MD, PA, VA, and WV, 1977-1983, Black-and-White High-Altitude Collection
# https://www.sciencebase.gov/catalog/item/55c50826e4b033ef5212bd4b
# text/csv  -  1
# ==================
# Field Notebooks from VA
# https://www.sciencebase.gov/catalog/item/5771405ae4b07657d1a6b9ff
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# text/csv  -  1
# application/vnd.ms-excel  -  1
# ==================
# Sinkhole Maps Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e93
# application/xml  -  1
# ==================
# Mineral Resources of VA (MRV) Collection
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ec0
# application/xml  -  1
# ==================
# Nevada Bureau of Mines and Geology Sample Collection Database
# https://www.sciencebase.gov/catalog/item/5494ba35e4b0a2b9adad8ee3
# text/csv  -  1
# ==================
# Collection of Photographic Slides and Historic Photos from Ohio
# https://www.sciencebase.gov/catalog/item/57f2863ae4b0bc0bebfff9b8
# application/xml  -  1
# text/csv  -  1
# ==================
# Collection of Lake Erie nearshore bathymetric profiles from Ohio
# https://www.sciencebase.gov/catalog/item/5228d5fae4b06291bed806dc
# application/xml  -  1
# ==================
# Collection of Lake Erie seismic profiles from Ohio
# https://www.sciencebase.gov/catalog/item/5228d69ee4b06291bed806e5
# application/xml  -  1
# ==================
# Rodgers Bedrock Compilation Sheets
# https://www.sciencebase.gov/catalog/item/52aa1f43e4b098bc4034b247
# text/plain; charset=windows-1252  -  1
# ==================
# Tennessee Geological Survey Tennessee Valley Authority Documents Collection
# https://www.sciencebase.gov/catalog/item/5016eff5e4b06fb5ce8b73e2
# text/csv  -  1
# ==================
# Collection of rock cores from Kansas
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df244
# application/xml  -  2
# ['25_122515_cores_full.xml', '25_122515_cores_full.upd.xml']
# ==================
# Nevada Bureau of Mines and Geology Nevada Mining District Files
# https://www.sciencebase.gov/catalog/item/4f4e49cbe4b07f02db5d877f
# text/csv  -  3
# ['MDMETADATA11012013_editedforprocessing.csv', 'MDMETADATA10262015CSV-FINAL.csv', 'MDMETADATA09222016-FINAL (1).csv']
# ==================
# Collection of Mud (gas) logs from Oklahoma
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df4d9
# text/plain  -  2
# ['Combo 2010+2011+NW Metadata.csv', '15_090550_Combo_2010_Metadata.csv']
# ==================
# Cores from industrial and mineral exploration sites in Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d228
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Billiton Metals and Ores rock cores
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df228
# ==================
# Collection of Photographs from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e4ac9e4b07f02db67c705
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Geologic Field Notes from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df0fa
# text/csv  -  3
# ['well_fieldnotes20160804.csv', 'well_fieldnotes20160808.csv', 'well_fieldnotes20160804 textcorrect.csv']
# ==================
# Collection of Geologic Photos and Images from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4a5fe4b07f02db634678
# application/xml  -  1
# ==================
# Collection of Paleontological samples (Weller Collection/Paleo Room) from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1d7
# application/xml  -  2
# ['27_124455_UL_5035819_20100105.xml', '20091229_143635_UL_5035819_20091229.xml']
# ==================
# Collection of Well logs from South Carolina
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df374
# text/plain; charset=windows-1252  -  1
# ==================
# Rock cores from permitted oil and gas wells in Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d225
# text/plain; charset=windows-1252  -  1
# ==================
# Washed well cuttings from permitted oil and gas wells in Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d22c
# text/plain; charset=windows-1252  -  1
# ==================
# Digital Geologic Map GIS Data (7.5' Quadrangles) in GeMS Schema
# https://www.sciencebase.gov/catalog/item/5bb26247e4b08583a5d59a48
# text/csv  -  1
# ==================
# Geological Survey of Alabama Cenozoic fossil collection
# https://www.sciencebase.gov/catalog/item/563cf58ce4b0831b7d61f267
# text/csv  -  7
# ['CZ2_fossils_GSA_2015-11-06.csv', '20121228_100045_NonToulminFossils2012_fixed (2).csv', 'CZ2_fossils_GSA_2014-10-27 (2).csv', 'Alabama Cenozoic Fossils 2015-2016 (2).csv', 'Alabama Cenozoic Fossils 2016-2017_NLedit.csv', 'Harrell data entry Cenozoics  2018.csv', 'Harrell data entry Cenozoics  2018 edit.csv']
# ==================
# Collection of Mine Maps from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df560
# text/csv  -  1
# ==================
# Coal Quality Data Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ec7
# application/xml  -  1
# ==================
# Geologic Sections Collection
# https://www.sciencebase.gov/catalog/item/55db6c93e4b0518e35470b43
# text/csv  -  18
# ['Culpeper_Completed.csv', 'HamptonRoads_Completed.csv', 'Northern_Virginia_Completed.csv', 'Richmond_Completed.csv', 'Salem_Completed.csv', 'Bristol_Completed.csv', 'Fredericksburg_Completed.csv', 'Lynchburg_Completed.csv', 'Staunton_Completed.csv', 'Culpeper_Completed_ScienceBaseFormat.csv', 'HamptonRoads_Completed_ScienceBaseFormat.csv', 'Northern_Virginia_Completed_ScienceBaseFormat.csv', 'Salem_Completed_ScienceBaseFormat.csv', 'Fredericksburg_Completed_ScienceBaseFormat.csv', 'Lynchburg_Completed_ScienceBaseFormat.csv', 'Richmond_Completed_ScienceBaseFormat.csv', 'Bristol_Completed_ScienceBaseFormat.csv', 'Staunton_Completed_ScienceBaseFormat.csv']
# application/vnd.ms-excel  -  9
# ['Bristol_Completed.xls', 'Culpeper_Completed.xls', 'Fredericksburg_Completed.xls', 'HamptonRoads_Completed.xls', 'Lynchburg_Completed.xls', 'Northern_Virginia_Completed.xls', 'Richmond_Completed.xls', 'Salem_Completed.xls', 'Staunton_Completed.xls']
# application/pdf  -  1
# ==================
# West Oatman Project mining collection
# https://www.sciencebase.gov/catalog/item/502e9936e4b0ca196f391cd6
# text/plain; charset=windows-1252  -  1
# ==================
# Arimetco Inc. mining collection
# https://www.sciencebase.gov/catalog/item/50636070e4b0a82e8b3d1da6
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Peter Robinson Blackline 24K Geologic Maps
# https://www.sciencebase.gov/catalog/item/5877dae2e4b0b8c259c48749
# text/csv  -  2
# ['RobinsonBlackline24KMapsCentralMA.csv', 'RobinsonBlackline24KMapsCentralMA_edit1.csv']
# ==================
# Geologic mine logs from New Jersey's mines pits and quarries.
# https://www.sciencebase.gov/catalog/item/57754152e4b07dd077c70878
# text/csv  -  1
# ==================
# Suhas Ghatge Field Notes Collection
# https://www.sciencebase.gov/catalog/item/561d2777e4b0cdb063e58525
# text/csv  -  1
# ==================
# Unpublished Connecticut Carbonate Set
# https://www.sciencebase.gov/catalog/item/5228df63e4b06291bed806fd
# text/plain; charset=windows-1252  -  1
# ==================
# Exhibition Flasks: Mineral Commodities of Maryland
# https://www.sciencebase.gov/catalog/item/4f4e4a82e4b07f02db64afd8
# text/plain  -  1
# ==================
# Maryland Macrofossils
# https://www.sciencebase.gov/catalog/item/4f4e4a82e4b07f02db64af56
# text/plain  -  1
# ==================
# Collection of Work Projects Administration Mineral Survey from Arkansas
# https://www.sciencebase.gov/catalog/item/55b236d0e4b09a3b01b535ca
# text/csv  -  1
# ==================
# Collection of Lake Michigan and Chain-of-Lakes Lakebed Core Sample Logs and Associated Data from Illinois
# https://www.sciencebase.gov/catalog/item/53c68ea8e4b0001bd51477eb
# application/xml  -  1
# ==================
# John W. Taber Collection
# https://www.sciencebase.gov/catalog/item/5a81c104e4b00f54eb30ea09
# application/xml  -  3
# ['Taber_NGGDPP_Upload_File.xml', 'sample.xml', 'sample_edit.xml']
# ==================
# MO Mineral Resource Microfilm
# https://www.sciencebase.gov/catalog/item/5060b03ae4b00fc20c4f3c8b
# text/plain  -  2
# ['metadata_microfilm.csv', 'metadata_microfilm_reels.csv']
# ==================
# West Virginia Oil and Gas Cores and Cuttings
# https://www.sciencebase.gov/catalog/item/57f7de35e4b0bc0bec09d0c7
# text/csv  -  3
# ['WVGES Data Presevation Metadata_2015.csv', 'WVGES Data Presevation Metadata_2015 edit.csv', 'DP_Oct2017_Pipe.csv']
# ==================
# Collection of Rock cuttings from OR
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df27b
# ==================
# Collection of hand samples from Alaska (DGGS)
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df4f6
# text/csv  -  1
# ==================
# Collection of Oil and Gas Well Paper Reports from Nevada
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df325
# text/csv  -  3
# ['OGMETADATA11012013.csv', 'OGMETADATA11012013_editedforprocessing.csv', 'OGMETADATA10272015_FINAL.csv']
# ==================
# Collection of Lead-Zinc Mine Logs and Mineral Concentration Data from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df10b
# application/xml  -  1
# ==================
# Collection of Geologic Hand Samples from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d0e4b07f02db5dafa3
# application/xml  -  2
# ['20091008_122755_handspec2.xml', '20101112_085644_handspecimens.xml']
# ==================
# Collection of U.S. Bureau of Mines rock cores in Maine
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da81f
# ==================
# Collection of geophysical logs of Florida
# https://www.sciencebase.gov/catalog/item/4f4e496fe4b07f02db5a3ddb
# text/csv  -  4
# ['FGS_LAS_metadata_UTF8.csv', 'FGS_Scan_metadata_UTF8.csv', 'FGS_LAS_metadata_UTF8_corrected.csv', 'FGS_Scan_metadata_UTF8_corrected.csv']
# ==================
# UGS Aerial Imagery Collection
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da74d
# application/xml  -  12
# ['05_061619_UDP3_Aerial.xml', '01_080036_NGGDPPMetadata_03012010_0748_AM.xml', '01_080634_NGGDPPMetadata_03012010_0748_AM.xml', '01_080920_NGGDPPMetadata_03012010_0748_AM.xml', '01_081438_NGGDPPMetadata_03012010_0814_AM.xml', '08_161959_Aerial_Metadata.xml', '03_094111_NGGDPPMetadata_06032010_0916_AM.xml', '11_142610_UDP2_Aerial.xml', 'UDP4_Aerial.xml', 'UDP5_Aerial.xml', 'UDP6_Aerial.xml', 'UDP7_Aerial.xml']
# ==================
# Collection of Hand samples from Ohio
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491dcf
# application/xml  -  3
# ['20100902_092117_OH_LakeErie_CERCCORE.xml', '20100902_092126_OH_LakeErie_GeoGrpCore.xml', '20100902_092135_OH_LakeErie_Misc_Samples.xml']
# ==================
# UGS GeoData Archive System
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df316
# application/xml  -  3
# ['UDP3_HAZDOCS.xml', '20110623_125501_UDP2_HAZDOCS.xml', 'UDP4_HAZDOCS.xml']
# text/csv  -  5
# ['UDP8_HAZDOCS_Corrected.csv', 'UT_UDP5.csv', 'UDP6_HAZDOCS2 (1).csv', 'UDP7_HAZDOCS_rev1 (2).csv', 'UDP9_HAZDOCS.csv']
# ==================
# Collection of Paper reports from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df444
# application/zip  -  1
# ==================
# Collection of rock cuttings from Kansas
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d8ee6
# application/xml  -  6
# ['25_123128_cuttings_full.xml', 'Kansas_well_cuttings_2014.xml', 'Kansas_Cuttings_2014-2015.xml', 'Kansas_Cuttings_2015-2016.xml', 'Kansas_Cuttings_2016-2017.xml', 'Kansas_Cuttings_2017-2018.xml']
# ==================
# Rock cores from Alabama oil and gas exploration wells
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d226
# text/plain; charset=windows-1252  -  4
# ['20090828_114513_OGB_Cores.csv', 'AdditionalCoreData_05-21-2014.csv', 'Cores_2009_USGS_03_02_2015.csv', 'Cores_2009_USGS_03_02_2015_ScienceBase_Format.csv']
# ==================
# Geological Survey of Alabama Mesozoic fossil collection
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d220
# text/csv  -  4
# ['20100810_140019_Mesozoic_Paleontology.csv', '20110927_133203_Toulmin_Paleontology.csv', 'Harrell data entry Mesozoics 2018.csv', 'Harrell data entry Mesozoics 2018 edit.csv']
# ==================
# Collection of Scanned Borehole Maps From New Jersey
# https://www.sciencebase.gov/catalog/item/561d2657e4b0cdb063e58522
# text/csv  -  1
# ==================
# Collection of Geochemical Data from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d913d
# text/csv  -  3
# ['Fitzgerald_chem_USGS_v03.csv', 'IGS-Geochem_2_18_2015.csv', 'GeochemData_IGS_2015.csv']
# ==================
# JABA, Inc. Tombstone records
# https://www.sciencebase.gov/catalog/item/5123a138e4b0c9f2bfcf8d72
# text/plain; charset=windows-1252  -  1
# ==================
# John E. Kinnison mining collection
# https://www.sciencebase.gov/catalog/item/502e93f4e4b0ca196f39086d
# text/plain; charset=windows-1252  -  1
# ==================
# Rich Volkert, Former Geologist, Field Maps
# https://www.sciencebase.gov/catalog/item/57755db0e4b07dd077c70902
# text/csv  -  1
# ==================
# Geologic Map Logs from New Jersey
# https://www.sciencebase.gov/catalog/item/561d2836e4b0cdb063e58528
# text/csv  -  1
# ==================
# Collection of Field Station Locations from Alaska
# https://www.sciencebase.gov/catalog/item/57c71fb3e4b0f2f0cebed0f0
# application/xml  -  2
# ['alaska_field_stations_57c71fb3e4b0f2f0cebed0f0.xml', 'alaska_field_stations_06222018.xml']
# ==================
# Collection of Arkansas Geological Survey Historic Rare Books
# https://www.sciencebase.gov/catalog/item/5773d8dfe4b07657d1a98fa0
# text/csv  -  2
# ['RareBookMetadata1.csv', 'RareBookMetadata1 (2).csv']
# ==================
# Collection of rock cuttings from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e4a73e4b07f02db6436bd
# application/xml  -  1
# ==================
# Collection of Well Logs from Michigan
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df27c
# text/csv  -  2
# ['logsdat4NGGDPP.csv', 'logsdat4NGGDPP (1).csv']
# ==================
# Silica Sample Analyses from VA
# https://www.sciencebase.gov/catalog/item/5249e70ce4b054aacd5ab555
# text/plain; charset=windows-1252  -  1
# ==================
# Carbonate Sample Analytical Data Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684edc
# application/xml  -  1
# ==================
# Collection of Drilling/completion reports from New Hampshire
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df203
# text/plain; charset=windows-1252  -  10
# ['029_BRENTWOOD_SUBMITTED_V2.csv', '071_DURHAM_SUBMITTED.csv', '082_EXETER_SUBMITTED.csv', '129_KINGSTON_SUBMITTED.csv', '135_LEE_SUBMITTED.csv', '176_NEWMARKET_SUBMITTED_V2.csv', '178_NEWTON_SUBMITTED.csv', '211_SANDOWN_SUBMITTED.csv', '059_DANVILLE_SUBMITTED.csv', '089_FREMONT_SUBMITTED.csv']
# ==================
# Nevada Bureau of Mines and Geology Serial Publications
# https://www.sciencebase.gov/catalog/item/5a162974e4b09fc93dd171ab
# text/csv  -  1
# ==================
# Collection of Bedrock Core Logs from Paddock Lead Mine, New Hampshire
# https://www.sciencebase.gov/catalog/item/5277d0f0e4b053a724a9972f
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Geotechnical Data from Transportation Projects in Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a48
# application/xml  -  2
# ['geotech_drillholes_1112017.xml', 'geotech_drillholes_1112017.xml']
# ==================
# Historical Aerial Photographs of Maryland, 1970-1974, High-Altitude Infrared Collection
# https://www.sciencebase.gov/catalog/item/55e0756ce4b0f42e3d040f03
# text/csv  -  1
# ==================
# Collection of John Kick Gravity Maps
# https://www.sciencebase.gov/catalog/item/5873df38e4b0a829a31e4850
# text/csv  -  2
# ['Kick48KGravityMapsCentralMA.csv', 'Kick48KGravityMapsCentralMA_edit.csv']
# ==================
# UGS Coal Drill Hole and Outcrop Data
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df0ff
# text/csv  -  7
# ['UDP5_CoalWell.csv', 'UDP6_CoalWell.csv', 'UDP7_CoalWell.csv', 'UPD7_CoalWell_reformatted.csv', 'UDP8_CoalWell.csv', 'UDP8_CoalWell_NLedit.csv', 'UDP9_CoalWell.csv']
# ==================
# Collection of Rock cores from Alaska
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3aa
# ==================
# Collection of Chips from TX
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1fa
# application/xml  -  1
# ==================
# Collection of Rock Cuttings from Texas
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1fd
# application/xml  -  3
# ['20090917_150731_crc2_export_20090914074342_P496.xml', '20090917_150731_crc2_export_20090914074342_P496_part2.xml', '20090917_150731_crc2_export_20090914074342_P496_part3.xml']
# text/csv  -  1
# ==================
# Tennessee Geological Survey Mineral Resources Documents Collection
# https://www.sciencebase.gov/catalog/item/4f4e4aaae4b07f02db66937a
# text/csv  -  2
# ['Tennessee_P1328_Mineral_Resources_Collection_Knoxville.csv', 'Tennessee_P1328_Mineral_Resources_Collection_Nashville.csv']
# ==================
# Collection of Water Well Sites from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d9185
# application/xml  -  1
# ==================
# Collection of Coal Outcrop Measurements from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4a51e4b07f02db629cfe
# application/xml  -  1
# ==================
# Collection of Rock Cores from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a49
# application/xml  -  2
# ['core_1112017.xml', 'core_652018.xml']
# ==================
# Florida oil and gas well rock cores from the Geological Survey of Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d229
# text/plain; charset=windows-1252  -  1
# ==================
# Washed water well cuttings from Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d22a
# text/plain; charset=windows-1252  -  3
# ['20090831_144859_Water_Wells.csv', '20110727_100210_AL_27_160339_Water_Wells.csv', '20090828_113833_Permitted_Wells.csv']
# ==================
# Historic Uranium Exploration Information in VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ebc
# application/xml  -  1
# ==================
# Borehole Database for VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684eda
# application/xml  -  3
# ['29_152409_BoreholeSamples1.xml', '20100630_160633_P841_BoreholeSamples1_revised.xml', '20100706_132021_BoreholeSamples4.xml']
# ==================
# UVA Mineral and Rock Specimens Collection
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e67
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Geologic Maps  from California
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df319
# text/plain; charset=windows-1252  -  2
# ['20101122_173416_CGS_RGM_Files1.csv', '20121228_071039_CGS_RGM_Files1.csv']
# ==================
# Aerial photography from California
# https://www.sciencebase.gov/catalog/item/4fb5480ce4b04cb937751d69
# text/csv  -  3
# ['CGS_AIRPHOTOS_collection_edit.csv', 'CGS_Aerial_Imagery_Database_Metadata-NGGDPP 2017 CSV Version.csv', 'CGS_Aerial_Imagery_Database_Metadata-NGGDPP 2017 CSV Version.csv']
# ==================
# Seismic Hazard Zonation Geotechnical Reports for California
# https://www.sciencebase.gov/catalog/item/56e85bb0e4b0f59b85d712ff
# text/csv  -  1
# ==================
# Collection of Coal Exploration Core Hole Logs from Tennessee
# https://www.sciencebase.gov/catalog/item/565cbe3ce4b071e7ea542f40
# text/csv  -  1
# ==================
# Tennessee Geological Survey Zinc Mining Reports and Maps Collection
# https://www.sciencebase.gov/catalog/item/542b0003e4b057766eed29e5
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Historic Photographs from Arkansas
# https://www.sciencebase.gov/catalog/item/5931cf70e4b0e9bd0eaa48d6
# text/csv  -  1
# ==================
# Collection of Digital Maps from NJ
# https://www.sciencebase.gov/catalog/item/4f4e48d5e4b07f02db548ffc
# application/xml  -  1
# ==================
# Collection of well logs from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e48b3e4b07f02db531927
# application/xml  -  1
# ==================
# Collection of Negatives From Illinois
# https://www.sciencebase.gov/catalog/item/59ef50bce4b0220bbd98d2f8
# application/xml  -  1
# ==================
# Maryland Rocks and Minerals
# https://www.sciencebase.gov/catalog/item/4f4e4a82e4b07f02db64b04b
# text/plain; charset=ISO-8859-1  -  1
# ==================
# Collection of hand samples from Michigan
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df289
# text/plain; charset=windows-1252  -  2
# ['20090918_144758_P1402.csv', '20090925_154611_P1402CSVOGS.csv']
# ==================
# Collection of Rock Core from Michigan
# https://www.sciencebase.gov/catalog/item/51dddff5e4b0f72b44722554
# text/csv  -  1
# ==================
# USGS Core Research Center (CRC) Collection of Cuttings
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2d2
# application/fgdc+xml  -  1
# ==================
# Collection of Drill Cuttings from MD
# https://www.sciencebase.gov/catalog/item/4f4e4a94e4b07f02db658d7f
# text/csv  -  1
# ==================
# Collection of Core Samples from Florida
# https://www.sciencebase.gov/catalog/item/4f4e496fe4b07f02db5a3df0
# text/csv  -  36
# ['28_112413_P582Charlotte_Dataset_100405_lds.csv', '28_112502_P582Desoto_Dataset_100512_avr.csv', '28_112530_P582Glades_Dataset_100329_avr.csv', '28_112638_P582Hardee_Dataset_100519_avr.csv', '28_112702_P582Highlands_Dataset_100507_lds.csv', '28_112727_P582IndianRiver_Dataset_100512_lds.csv', '28_112808_P582Martin_Dataset_100323_lds.csv', '28_112843_P582Okeechobee_Dataset_100506_avr.csv', '28_112914_P582Sarasota_Dataset_100412_lds.csv', '28_112947_P582StLucie_Dataset_100330_lds.csv', '20090923_151138_pipe_MO_090615_nad27.csv', '20091020_125417_P582CR_090616_nad27.csv', '20091022_084932_P582PB_090616_nad27.csv', '20091022_085033_P582LE_090616_nad27.csv', '20091022_085117_P582HY_090616_nad27.csv', '20091022_085610_P582BW_090616_nad27.csv', '20091022_085738_P582DD_090615_nad27.csv', '20091109_114622_P582CR_090616_nad27.csv', '20091109_115145_P582PB_090616_nad27.csv', '20091109_115325_P582LE_090616_nad27.csv', '20091109_115453_P582HY_090616_nad27.csv', '20091109_115714_P582BW_090616_nad27.csv', '20091109_115802_P582DD_090615_nad27.csv', '20091109_115834_P582MO_090615_nad27.csv', '20091214_070959_P582NGGDPP_Phase_II_upload_file_v1_lafedit.csv', '20101005_145709_P582Citrus_Dataset_100527_avr.csv', '20101005_145746_P582Hernando_Dataset_100721_swb.csv', '20101005_145814_P582Lake_Dataset_100624_avr.csv', '20101005_145842_P582Levy_Dataset_100824_swb.csv', '20101005_145906_P582Marion_Dataset_100729_avr.csv', '20101005_145955_P582Orange_Dataset_100824_avr.csv', '20101005_150017_P582Pasco_Dataset_100714_swb.csv', '20101005_150038_P582Sumter_Dataset_100621_swb.csv', '20091030_112534_P582Statemap_Q1982_Q1983_090616_nad27.csv', 'FGS_Core_Collection_2018.csv', 'FGS_Core_Collection_2018_edit.csv']
# ==================
# Collection of Rock Cuttings from Florida
# https://www.sciencebase.gov/catalog/item/4f4e496fe4b07f02db5a3df2
# text/csv  -  36
# ['28_113024_P584Charlotte_Dataset_100405_lds.csv', '28_113141_P584Desoto_Dataset_100512_avr.csv', '28_113209_P584Glades_Dataset_100329_avr.csv', '28_113232_P584Hardee_Dataset_100519_avr.csv', '28_113300_P584Highlands_Dataset_100507_lds.csv', '28_113326_P584IndianRiver_Dataset_100512_lds.csv', '28_113349_P584Martin_Dataset_100323_lds.csv', '28_113427_P584Okeechobee_Dataset_100506_avr.csv', '28_113453_P584Sarasota_Dataset_100412_lds.csv', '28_113521_P584StLucie_Dataset_100330_lds.csv', '20091022_084513_P584MO_090615_nad27.csv', '20091022_084639_P584PB_090616_nad27.csv', '20091022_084906_P584Misc_GL_OS_SR_090616_nad27.csv', '20091022_085008_P584LE_090616_nad27.csv', '20091022_085101_P584HY_090616_nad27.csv', '20091022_085153_P584CR_090616_nad27.csv', '20091022_085218_P584BW_090616_nad27.csv', '20091030_112513_P584Statemap_Q1982_Q1983_090616_nad27.csv', '20091109_114537_P584DD_090615_nad27.csv', '20091109_115056_P584Misc_GL_OS_SR_090616_nad27.csv', '20091109_115231_P584LE_090616_nad27.csv', '20091109_115408_P584HY_090616_nad27.csv', '20091109_115605_P584CR_090616_nad27.csv', '20091109_115641_P584BW_090616_nad27.csv', '20091109_114710_P584PB_090616_nad27.csv', '20091214_070921_P584NGGDPP_Phase_II_upload_file_v1_lafedit.csv', '20101005_150057_P584Citrus_Dataset_100527_avr.csv', '20101005_150140_P584Hernando_Dataset_100721_swb.csv', '20101005_150303_P584Levy_Dataset_100824_swb.csv', '20101005_150411_P584Marion_Dataset_100729_avr.csv', '20101005_150447_P584Orange_Dataset_100824_avr.csv', '20101005_150507_P584Pasco_Dataset_100714_swb.csv', '20101005_150524_P584Sumter_Dataset_100621_swb.csv', '20101006_115203_P584Lake_Dataset_100624_avr.csv', 'FGS_Cuttings_Collection_2018.csv', 'FGS_Cuttings_Collection_2018_edit.csv']
# ==================
# Collection of Knox Mining Corporation rock cores
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df230
# ==================
# Collection of Geologic Well Logs from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df29a
# text/csv  -  3
# ['well_striplogs20160804.csv', 'wells_gp_logs20160804.csv', 'WellLogs20180717.csv']
# ==================
# Collection of Engineering Files from Nevada
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1bf
# text/plain  -  2
# ['08_122258_fin_p698_nbmg.txt', '08_122335_fin_p698_nbmg.csv']
# ==================
# Collection of Thin sections and polished sections from Ohio
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491ddd
# application/xml  -  1
# ==================
# Collection of Rock cores from New Jersey
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2f0
# application/xml  -  1
# ==================
# Collection of rock hand specimens from Wisconsin
# https://www.sciencebase.gov/catalog/item/4f4e49e8e4b07f02db5e87fe
# application/xml  -  1
# ==================
# Collection of Hand samples from MN
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da9bb
# text/csv  -  3
# ['15_093457_mgs_hsi_ndcprep.csv', 'mgs_hsi_ndc2014.csv', 'mgs_hsi_ndc2015.csv']
# ==================
# Collection of drilling/completion reports from Massachusetts
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df216
# text/plain  -  1
# ==================
# Collection of well logs from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da981
# application/xml  -  1
# ==================
# Collection of geologic field notes from Washington State
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3a8
# text/csv  -  3
# ['field_sites_metadata_20180720.csv', 'field_notebook_metadata_20180720.csv', 'WA_notebooks.csv']
# ==================
# Collection of 1930 Aerial Photos
# https://www.sciencebase.gov/catalog/item/58e52af4e4b09da679997c67
# text/csv  -  1
# ==================
# Collection of Chicago-area deep borehole data from Illinois
# https://www.sciencebase.gov/catalog/item/53c68f71e4b0001bd51477ef
# application/xml  -  1
# ==================
# Collection of well descriptions from Delaware
# https://www.sciencebase.gov/catalog/item/5409caaee4b0b2c50ef7f4d0
# text/plain; charset=windows-1252  -  3
# ['DGS Well Record Metadata for FY13 NGGDPP.csv', 'DGS Well Record Metadata for FY13 NGGDPP.csv', 'DGS Well Metadata for FY14 NGGDPPF_REMAINING THIRD.csv']
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# ==================
# Unpublished Smith Map Set of Mines and Quarries of Connecticut
# https://www.sciencebase.gov/catalog/item/5294d093e4b01cca2b11df4a
# application/pdf  -  1
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of historical clay mineralogy XRD analysis data from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2c9
# application/xml  -  2
# ['UL_16052426_20120813.xml', '20110805_090212_UL_16052426_20110805.xml']
# ==================
# Grover Heinrichs mining collection
# https://www.sciencebase.gov/catalog/item/502e85ece4b0ca196f38d852
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Historic Media Documents from Arkansas
# https://www.sciencebase.gov/catalog/item/592dc706e4b092b266efea5d
# text/csv  -  1
# ==================
# George M. Colvocoresses mining collection
# https://www.sciencebase.gov/catalog/item/4fce7918e4b05b6193661483
# text/plain; charset=windows-1252  -  1
# ==================
# Fred Hohne mining collection
# https://www.sciencebase.gov/catalog/item/502e83e8e4b0ca196f38d185
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Thin Sections from Michigan
# https://www.sciencebase.gov/catalog/item/5b856479e4b05f6e321d03eb
# text/csv  -  1
# ==================
# Historical Aerial Photographs of Maryland, 1936-1991, Quad Collection
# https://www.sciencebase.gov/catalog/item/53fcdfe8e4b0413fd75eab5b
# text/plain; charset=windows-1252  -  2
# ['tblUploadMetadata_QuadAPMD_201408.csv', 'tblUploadMetadata_QuadAPMD_201408.csv']
# ==================
# Collection of Rock Core Analyses from Michigan - 2013 addition
# https://www.sciencebase.gov/catalog/item/51e034b2e4b0d332bf22f5b8
# text/plain; charset=windows-1252  -  1
# ==================
# Montana Mining Map File Collection
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df156
# text/csv  -  1
# ==================
# Richard B. Berg Collection
# https://www.sciencebase.gov/catalog/item/5a81bda8e4b00f54eb30e9ea
# application/xml  -  3
# ['NGGDPP_Upload_Table.xml', 'sample.xml', 'sample_edit2.xml']
# ==================
# Missouri Geological Survey Unpublished Manuscript Collection
# https://www.sciencebase.gov/catalog/item/5b50d5f8e4b06a6dd185e6dc
# text/csv  -  2
# ['MGSManuscriptsfile2018.csv', 'MGSManuscriptsfile2018_rev.csv']
# ==================
# Collection of aerial photos owned by the Kansas Geological Survey
# https://www.sciencebase.gov/catalog/item/5ba8e4d4e4b08583a5ca0375
# application/xml  -  1
# ==================
# Collection of Bedrock Borehole Videos from New Hampshire
# https://www.sciencebase.gov/catalog/item/5277e783e4b01691c8aa39ba
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Bedrock Core Logs from Copperville Mine, New Hampshire
# https://www.sciencebase.gov/catalog/item/5277e0ace4b01691c8aa303d
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Sand and Gravel Mining in Lake Erie from Ohio
# https://www.sciencebase.gov/catalog/item/5228d572e4b06291bed806d8
# application/xml  -  1
# ==================
# Paleontological Collection from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ea0
# application/xml  -  1
# ==================
# Collection of Rock Cores from TX
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3d2
# application/xml  -  1
# ==================
# Neil Wills Well Reports from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2d0
# text/csv  -  2
# ['P758_Descriptions_delim.csv', '20160711_P758_Descriptions.csv']
# ==================
# UGS UCRC Crude Oil Samples
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df32b
# application/xml  -  1
# ==================
# Tennessee Geological Survey Collection of Field Notebooks, Maps, and Photographs from Tennessee
# https://www.sciencebase.gov/catalog/item/4f4e4a53e4b07f02db62afb1
# text/csv  -  1
# ==================
# Collection of Paper reports from Ohio
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491dd0
# application/xml  -  4
# ['20100902_092224_OH_SG_PebbleCountsResults.xml', '20100902_092233_OH_SG_RatioStudy.xml', '20100902_092241_OH_SG_Resources.xml', '20100902_092255_OH_SG_SieveAnalysis.xml']
# ==================
# Collection of Rock cores from Oklahoma
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1d3
# text/plain  -  1
# ==================
# Collection of Geologic Maps from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da9cf
# text/csv  -  1
# ==================
# Collection of Rock Cuttings from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a4e
# application/xml  -  2
# ['oilgas_cuttings_1112017.xml', 'oilgas_cuttings_1112017.xml']
# ==================
# Collection of Rock Core Analyses from Michigan
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1cf
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Hardrock Mineral Core from Alaska
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da76d
# text/csv  -  2
# ['bom_rebox_project_NDC_metadata_v1.csv', 'blm_pulps_ndc_metadata.csv']
# ==================
# Collection of Outcrop Locations from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a47
# application/xml  -  1
# ==================
# Collection of maps from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df44d
# application/xml  -  1
# ==================
# Collection of Petroleum Hydrocarbon Chromatographic Analyses of Drill Cuttings and Core Chips from Michigan
# https://www.sciencebase.gov/catalog/item/556e1b5ee4b0d9246a9f9a96
# text/plain; charset=windows-1252  -  1
# ==================
# Mine crib sheets
# https://www.sciencebase.gov/catalog/item/57755162e4b07dd077c708ab
# text/csv  -  1
# ==================
# Publication Index from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ea5
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# text/csv  -  2
# ['Publications edit.csv', 'Publications.csv']
# ==================
# Biennial Reports of the Commissioners of the State Geological and Natural History Survey Collection
# https://www.sciencebase.gov/catalog/item/520b8524e4b0d6ca46067df0
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Well Cuttings from New Hampshire
# https://www.sciencebase.gov/catalog/item/4f4e49a2e4b07f02db5bebf4
# text/plain  -  1
# ==================
# Collection of Paper reports from New Hampshire
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df372
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Well logs from New Hampshire
# https://www.sciencebase.gov/catalog/item/4f4e48b4e4b07f02db532fc8
# text/plain; charset=windows-1252  -  1
# ==================
# Vermont Geological Survey Collection of Oil and Gas Exploration Well Records
# https://www.sciencebase.gov/catalog/item/52f25201e4b0a6f0bd498b93
# text/plain; charset=windows-1252  -  1
# ==================
# Unpublished University of Connecticut Geology Department Field School Maps
# https://www.sciencebase.gov/catalog/item/530e5350e4b0929320b22a4b
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of outcrop descriptions from Delaware
# https://www.sciencebase.gov/catalog/item/5409ca49e4b0b2c50ef7f4ce
# text/plain; charset=windows-1252  -  2
# ['DGS Outcrop Metadata for FY13 NGGDPP.csv', 'DGS Outcrop Metadata for FY13 NGGDPP.csv']
# ==================
# Petroleum Geophysical Logs from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e4a72e4b07f02db642c16
# text/plain; charset=windows-1252  -  2
# ['25_145541_P747_OilGasLogs.csv', '20110817_104119_P747_Petroleum_Logs.csv']
# ==================
# Scanned unpublished geologic maps from Alabama
# https://www.sciencebase.gov/catalog/item/4f4e4abce4b07f02db6735a7
# text/plain; charset=windows-1252  -  3
# ['20120403_082438_27_133132_Scanned_Maps.csv', '20110928_090611_27_133132_Scanned_Maps.csv', '20110927_133132_Scanned_Maps.csv']
# ==================
# Historical (1966-1974) Aerial Photographs of the Rockville-Laurel Area, Montgomery County, Maryland
# https://www.sciencebase.gov/catalog/item/5069f121e4b046e0dfdbbc73
# text/csv  -  1
# ==================
# Bathymetric Surveys for Maryland Reservoirs and Coastal Waters
# https://www.sciencebase.gov/catalog/item/4f4e4a4de4b07f02db627130
# text/plain; charset=windows-1252  -  1
# ==================
# Historical Air Photo Index Maps of Maryland, 1936-1990
# https://www.sciencebase.gov/catalog/item/4f70c4dee4b08a0b754221e1
# text/csv  -  1
# ==================
# New Jersey Zinc Company zinc exploration maps and associated soil logs
# https://www.sciencebase.gov/catalog/item/5b157ee0e4b092d9651e2043
# text/csv  -  1
# ==================
# Edwin Noel Pennebaker mining collection
# https://www.sciencebase.gov/catalog/item/4fff6634e4b08406cdf6564e
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of rock cuttings from Arizona
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491e34
# application/xml  -  1
# ==================
# Walter E. Heinrichs, Jr. mining collection
# https://www.sciencebase.gov/catalog/item/50005cdbe4b001bafe1d463a
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Documents from the Fluorspar District of Southern Illinois
# https://www.sciencebase.gov/catalog/item/55f98a4be4b05d6c4e501427
# application/xml  -  1
# ==================
# ...
# ==================
# Rock cores from drill holes in New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e48b1e4b07f02db5305cf
# text/plain  -  2
# ['25_145031_P743_Core.csv', '24_123924_P743_Core.csv']
# ==================
# Petroleum well tests of New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df31b
# text/plain  -  1
# ==================
# Geological Survey of Alabama Paleozoic fossil collection
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d224
# text/csv  -  3
# ['PzFossilUpload_2014_04_14.csv', 'Harrell data entry Paleozoics 2018.csv', 'Harrell data entry Paleozoics 2018 edit.csv']
# ==================
# Collection of Geothermal Well Files from Nevada
# https://www.sciencebase.gov/catalog/item/4f4e49cbe4b07f02db5d877d
# text/plain; charset=ISO-8859-1  -  1
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Thin sections from MN
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da943
# text/csv  -  3
# ['16_091631_mgs_tsi_ndcprep.csv', 'mgs_tsi_ndc2014.csv', 'mgs_tsi_ndc2015.csv']
# ==================
# Collection of Maps from New Hampshire
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491dca
# text/plain  -  1
# ==================
# Collection of Aerial photographs from Oklahoma
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df4da
# text/csv  -  4
# ['Aerial Metadata FY14.csv', 'FY14 Aerial Photo Metadata - Oklahoma Geological Survey.csv', 'FY14 Aerial Photo Metadata - Oklahoma Geological Survey (3).csv', 'FY15 Aerial Photo Metadata - Oklahoma Geological Survey2.csv']
# ==================
# Collection of Historic Production Data for Michigan from the Albion Scipio field
# https://www.sciencebase.gov/catalog/item/520d2c68e4b081fa6136d4e6
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Rock Cuttings from Michigan
# https://www.sciencebase.gov/catalog/item/51dde0d3e4b0f72b44722560
# text/csv  -  3
# ['20130709_R1403-cuttings.csv', 'cuttingsdat4NGGDPP.csv', 'cuttingsdata2018_1.csv']
# ==================
# Inventory of Items in the Leo Hall Collection, Geosciences Department, University of Massachusetts Amherst
# https://www.sciencebase.gov/catalog/item/57c6f8f4e4b0f2f0cebed061
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# text/csv  -  1
# ==================
# Collection of Chesapeake Energy Corp cores and cuttings
# https://www.sciencebase.gov/catalog/item/50607e27e4b005cf46b28e70
# application/xml  -  2
# ['NGGDPP_ChesapeakeCuttings.xml', 'NGGDPP_ChesapeakeCuttings1.xml']
# ==================
# Collection of Lithology logs from New Jersey
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2fb
# text/plain; charset=windows-1252  -  1
# ==================
# Oxford Township Residential Well Logs from Arsenic in Ground Water Study
# https://www.sciencebase.gov/catalog/item/57753b66e4b07dd077c7085e
# text/csv  -  1
# ==================
# Monzonite Photograph Collection
# https://www.sciencebase.gov/catalog/item/561d290be4b0cdb063e5852a
# text/csv  -  1
# ==================
# Historical Aerial Photographs of Maryland, 1987-1989, USGS NWIS Well-Related Collection
# https://www.sciencebase.gov/catalog/item/55e4935fe4b05561fa208470
# text/csv  -  1
# ==================
# Collection of Louisiana Geological Survey Publications
# https://www.sciencebase.gov/catalog/item/5612cd9fe4b0ba4884c609ff
# text/csv  -  1
# ==================
# Historical Aerial Photographs of Maryland, 1937-1990, County Collection
# https://www.sciencebase.gov/catalog/item/4f4e4a94e4b07f02db658dba
# text/csv  -  2
# ['tblUploadMetadata_P1603_CoAPMD_081018.csv', 'tblUploadMetadata_P1603_CoAPMD_081018.csv']
# ==================
# Clay Sample Analyses from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ee3
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of mine reports and records from Washington State
# https://www.sciencebase.gov/catalog/item/4fbfe433e4b05139c9cc62c0
# application/xml  -  3
# ['wa_metal_mines.xml', 'wa_metal_mines_new.xml', '20121024_124153_wa_metal_mines_new.xml']
# ==================
# Economic Geology Mineral Resource Files from VA
# https://www.sciencebase.gov/catalog/item/512e83a8e4b0171ea93890d1
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of 1979 Aerial Photos
# https://www.sciencebase.gov/catalog/item/59fa23e2e4b0531197aff418
# text/csv  -  1
# ==================
# Collection of Rock Cores from Arkansas
# https://www.sciencebase.gov/catalog/item/4fac0b76e4b07752ae5cf1eb
# application/xml  -  1
# text/html  -  1
# ==================
# Collection of Out-of-State Geologic Samples
# https://www.sciencebase.gov/catalog/item/5bd2608be4b0b3fc5ce32547
# text/csv  -  2
# ['FGS_OOS_Collection_2018.csv', 'FGS_OOS_Collection_2018_edit.csv']
# ==================
# Collection of Mines and Prospects Database from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e4ac9e4b07f02db67c9a3
# text/csv  -  6
# ['0_SciBas_MPdb_Export.csv', '0_SciBas_MPdb_Export.csv', '0_SciBas_MPdb_Export.csv', 'SciBas_MPdb_Export.csv', 'SciBas_MPdb_Export.csv', '0_SciBasMPDBv2.csv']
# ==================
# Collection of geochemical data (database/interactive app) from Idaho
# https://www.sciencebase.gov/catalog/item/54e78ff8e4b02d776a66a104
# text/csv  -  2
# ['20180722_GC_OUTPUT.csv', '20180727_GC_Bonn_OUTPUT.csv']
# ==================
# Collection of Paleontological Samples (Microfossils) from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df139
# application/xml  -  1
# ==================
# Collection of well logs from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df210
# application/xml  -  1
# ==================
# Collection of Sediment Cores from MD, 1984-1997, MD Continental Shelf
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df370
# text/plain  -  1
# ==================
# Collection of Well logs from Ohio
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491dde
# application/xml  -  1
# ==================
# Collection of drilling/completion reports from Kansas water wells
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df2a1
# application/xml  -  4
# ['Kansas_water_well_2014-2015_work.xml', 'Kansas_water_well_2015-2016_work.xml', 'Kansas_water_well_2016-2017_work.xml', 'Kansas_water_well_2017-2018_work.xml']
# ==================
# Core Analysis of New Mexico Wells
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d9197
# text/plain; charset=windows-1252  -  2
# ['25_145708_P751_CoreAnalysis.csv', '20110817_103510_P751_Core_Analysis.csv']
# ==================
# Collection of Rock cores from OR
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df56f
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Geochemical Data from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da96e
# application/xml  -  1
# ==================
# Collection of Coal Reports from Tennessee
# https://www.sciencebase.gov/catalog/item/4f4e4aaae4b07f02db669372
# ==================
# Collection of Paleontological samples from OR
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3a5
# ==================
# John Sanders New Haven Harbor Project
# https://www.sciencebase.gov/catalog/item/530e53c2e4b0929320b22a57
# text/plain; charset=windows-1252  -  1
# ==================
# Doug K. Martin mining collection
# https://www.sciencebase.gov/catalog/item/4ff5e0a2e4b03b1a74b5782e
# text/plain; charset=windows-1252  -  1
# ==================
# Petrographic thin sections from Alabama
# https://www.sciencebase.gov/catalog/item/50b6374be4b099a922c3ab7b
# text/plain  -  1
# ==================
# Strip Lithology logs from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e4a64e4b07f02db6380ac
# text/plain; charset=windows-1252  -  2
# ['28_082553_P753_striplogs.csv', '20110817_103316_p753_strip_logs.csv']
# text/csv  -  2
# ['P753_Striplogs_delim.csv', '20160711_P753_Striplogs.csv']
# ==================
# Collection of Scanned Index Cards from Bureau of Economic Geology Core Research Center Archive
# https://www.sciencebase.gov/catalog/item/55357d5fe4b0b22a1580799a
# text/plain; charset=windows-1252  -  3
# ['scanned_index_cards_trimmed2.csv', 'indexcards.csv', 'indexcards_ScienceBase_format.csv']
# ==================
# Hand samples from Alabama coalfields
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d21f
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Rock Cores from Iowa
# https://www.sciencebase.gov/catalog/item/4f4e49d0e4b07f02db5db553
# text/csv  -  3
# ['well_sample_cores20160804.csv', 'geocore20170919.csv', 'geocore20171113.csv']
# ==================
# Coal drill hole logs from New Mexico
# https://www.sciencebase.gov/catalog/item/4f4e49cbe4b07f02db5d87b8
# text/plain  -  3
# ['28_082809_P1269_coallogs.csv', '28_084316_P1269_coallogs.csv', '28_084651_P1269_coallogs.csv']
# ==================
# Collection of Maps from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e4779e4b07f02db47f48e
# ==================
# Collection of Paper reports from Idaho
# https://www.sciencebase.gov/catalog/item/4f4e49cae4b07f02db5d74c4
# text/plain; charset=windows-1252  -  2
# ['05_104144_ID_CollectionMetadata--IGS_Mines_Data.csv', '20111103_122155_2010_IGS_Sunshine_files_2.csv']
# ==================
# Collection of Photographs from Delaware
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da8a7
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Paper reports from Ohio
# https://www.sciencebase.gov/catalog/item/4f4e479de4b07f02db491dd1
# application/xml  -  1
# ==================
# Collection of Field notebooks from MN
# https://www.sciencebase.gov/catalog/item/4f4e49cce4b07f02db5d914b
# text/plain  -  1
# ==================
# Collection of Rock cores from South Carolina
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df350
# text/plain; charset=windows-1252  -  1
# ==================
# Rock Sample Repository from VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684e81
# application/xml  -  1
# ==================
# Geophysical Data Collection for VA
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684eae
# application/xml  -  1
# ==================
# Rock Cores from Virginia
# https://www.sciencebase.gov/catalog/item/4f4e4ad9e4b07f02db684ea9
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet  -  1
# text/csv  -  2
# ['Core.csv', 'VA_core_edit.csv']
# application/vnd.ms-excel  -  1
# ==================
# Collection of Northern Joint Venture rock cores
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df19a
# ==================
# Collection of Great Northern Paper rock cores
# https://www.sciencebase.gov/catalog/item/4f4e49cfe4b07f02db5da83f
# ==================
# Collection of Maps from Arkansas
# https://www.sciencebase.gov/catalog/item/4fac0cbbe4b07752ae5cf1f4
# text/csv  -  1
# ==================
# Collection of Rock Cuttings from Arkansas
# https://www.sciencebase.gov/catalog/item/4fb3cce8e4b02ce58576d605
# application/xml  -  5
# ['ArkGeoSurv_RockCutting_metadata.xml', '20120502_103405_ArkGeoSurv_CoreWH_metadata1.xml', '20120502_103601_ArkGeoSurv_CoreWH_metadata2.xml', '20120510_140744_mods1.xml', '20120510_134003_ArkGeoSurv_CoreWH_metadata1.xml']
# ==================
# Roland Mulchay mining collection
# https://www.sciencebase.gov/catalog/item/4fdf78dde4b01daa093be125
# text/plain; charset=windows-1252  -  1
# ==================
# Reconstruction Finance Corporation Arizona records
# https://www.sciencebase.gov/catalog/item/4fdfa473e4b01daa093be12b
# text/plain; charset=windows-1252  -  1
# ==================
# Geophysical Logs, Western Maryland Deep Wells
# https://www.sciencebase.gov/catalog/item/4f4e4a81e4b07f02db64a65e
# text/plain; charset=windows-1252  -  1
# ==================
# Historical Aerial Photographs of Fenwick and Assateague Islands, Maryland, 1952-1964
# https://www.sciencebase.gov/catalog/item/4f4e4aafe4b07f02db66cf18
# text/plain; charset=windows-1252  -  2
# ['tblUploadMetadata_P1691_AP_OC_v2_201208.csv', '20110428_131946_tblUploadMetadata_P1691_AP_OC.csv']
# ==================
# Geological Survey of Alabama Cenozoic fossils collected by paleontologist Lyman Toulmin
# https://www.sciencebase.gov/catalog/item/4f4e4acae4b07f02db67d222
# text/plain; charset=windows-1252  -  2
# ['20110928_153811_28_071743_Cenozoic_Paleontology_Toulmin.csv', 'Toulmin2013.csv']
# ==================
# Collection of unpublished Geochemical Data from Idaho
# https://www.sciencebase.gov/catalog/item/56214998e4b06217fc478c17
# text/csv  -  2
# ['IGS_20170824_Bonnichsen.csv', 'IGS_2015_Fitzgerald.csv']
# ==================
# Collection of Well Mud Logs from Michigan
# https://www.sciencebase.gov/catalog/item/51e01c95e4b0d332bf22f44c
# text/csv  -  2
# ['20130709_R1537-geologicallogs_fixed.csv', 'R1537_NewMudLogs_2016 (1).csv']
# ==================
# Collection of Limestone Samples from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4ac0e4b07f02db676d75
# application/xml  -  1
# ==================
# Collection of Geophysical Logs from TX
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df3b4
# application/xml  -  10
# ['20090917_153205_crc2_export_20090914074342_P498_part1.xml', '20090917_153205_crc2_export_20090914074342_P498_part2.xml', '20090917_153205_crc2_export_20090914074342_P498_part3.xml', '20090917_153205_crc2_export_20090914074342_P498_part4.xml', '20090917_153205_crc2_export_20090914074342_P498_part5.xml', '20090917_153205_crc2_export_20090914074342_P498_part6.xml', '20090917_153205_crc2_export_20090914074342_P498_part7.xml', '20090917_153205_crc2_export_20090914074342_P498_part8.xml', '20090917_153205_crc2_export_20090914074342_P498_part10.xml', '20090917_153205_crc2_export_20090914074342_P498_part9.xml']
# ==================
# Collection of Digital Photographs of Rock Cores from TX
# https://www.sciencebase.gov/catalog/item/52ab3897e4b078ad3e41b07b
# application/xml  -  1
# ==================
# NGGDPP Wisconsin GS Harvested Items
# https://www.sciencebase.gov/catalog/item/4f4e4762e4b07f02db47dffb
# application/xml  -  1
# ==================
# UGS UCRC Surface Samples
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df11e
# application/xml  -  1
# ==================
# Collection of Oil and Gas Well Logs from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e4b32e4b07f02db6b4a3d
# application/xml  -  20
# ['oilgas_1112017.xml', 'oilgas_1202017.xml', 'oilgas_2142017_1.xml', 'oilgas_2142017_1a.xml', 'oilgas_2142017_2.xml', 'oilgas_2142017_2b.xml', 'oilgas_2142017_3.xml', 'oilgas_2142017_3b.xml', 'oilgas_12132017_1.xml', 'oilgas_12132017_1.xml', 'oilgas_12132017_2.xml', 'oilgas_12152017_3.xml', 'oilgas_12152017_4.xml', 'oilgas_12152017_5.xml', 'oilgas_11162018_1.xml', 'oilgas_11162018_2.xml', 'oilgas_11162018_3.xml', 'oilgas_11162018_4.xml', 'oilgas_11162018_5.xml', 'oilgas_11162018_6.xml']
# ==================
# UGS Geologic Map Collection
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df209
# application/xml  -  2
# ['21_154512_Map_Metadata.xml', '20111206_135330_06_133105_2011_Maps.xml']
# text/html  -  1
# text/csv  -  8
# ['UDP4_Maps.csv', 'UDP5_Maps.csv', 'UDP6_Maps.csv', 'UPD7_Maps.csv', 'UPD7_Maps_reformat.csv', 'UDP8_Maps.csv', 'UPD8_Maps_reformat.csv', 'UPD9_Maps.csv']
# ==================
# Collection of Coal Quality Analyses from Kentucky
# https://www.sciencebase.gov/catalog/item/4f4e49f2e4b07f02db5eef23
# application/xml  -  1
# ==================
# Collection of aerial photos owned by the Kansas Geological Survey
# https://www.sciencebase.gov/catalog/item/59de2732e4b05fe04ccd3940
# application/xml  -  1
# ==================
# Collection of Nevada Geology Files from Nevada
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df1e4
# text/plain  -  1
# ==================
# Rock Chips from Cores of New Mexico Drill Holes
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df104
# text/plain  -  1
# ==================
# Petroleum well history for New Mexico wells
# https://www.sciencebase.gov/catalog/item/4f4e49d8e4b07f02db5df320
# text/plain; charset=windows-1252  -  1
# ==================
# Collection of Hand Samples (Carozzi Collection) from Illinois
# https://www.sciencebase.gov/catalog/item/4f4e49f9e4b07f02db5f3bd8
# application/xml  -  1
# ==================
# Total: 334
